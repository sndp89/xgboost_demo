# %% [markdown]
# # XGBoost Model running in parallel on GPU's
# #### Sample data use case: likely to upgrade to Hispanic Tier

# %% [markdown]
# ## Check for number of GPU's

# %%
# !nvidia-smi
# Out:
# Thu Aug  1 14:14:21 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.79       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-DGXS...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   40C    P0    38W / 300W |      0MiB / 16128MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-DGXS...  On   | 00000000:08:00.0 Off |                    0 |
# | N/A   40C    P0    39W / 300W |      0MiB / 16128MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-DGXS...  On   | 00000000:0E:00.0 Off |                    0 |
# | N/A   40C    P0    40W / 300W |      0MiB / 16128MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-DGXS...  On   | 00000000:0F:00.0 Off |                    0 |
# | N/A   39C    P0    37W / 300W |     27MiB / 16128MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    3      1908      G   /usr/lib/xorg/Xorg                             9MiB |
# |    3      1956      G   /usr/bin/gnome-shell                          15MiB |
# +-----------------------------------------------------------------------------+

# %%
# !nproc
# Out:
# 40

# %% [markdown]
# ## CUDA Version
#
# Next, let's see what CUDA version we have.

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %% [markdown]
# ## Load our libraries

# %%
#import cudf; print('cuDF Version:', cudf.__version__)
#import cuml; print('cuML Version:', '0.2.0')
#import dask; print('dask Version:', dask.__version__)
# import dask_gdf; print('dask_gdf Version:', dask_gdf.__version__)
# import dask_xgboost; print('dask_xgboost Version:', dask_xgboost.__version__)
#import numba; print('numba Version:', numba.__version__)
import numpy; print('numpy Version:', numpy.__version__)
import matplotlib; print('matplotlib Version:', matplotlib.__version__)
import pandas; print('pandas Version:', pandas.__version__)
import pyarrow; print('pyarrow Version:', pyarrow.__version__)


#xgboost library has been re-compiled with NCCL to support running on GPU
import xgboost; print('XGBoost Version:', xgboost.__version__)
# Out:
# numpy Version: 1.16.2
# matplotlib Version: 3.0.2
# pandas Version: 0.24.1
# pyarrow Version: 0.12.1
# XGBoost Version: 0.81

# %% [markdown]
# ## Load/Simulate data
#
# ### Load data
#
# We can load the data using `pandas.read_csv`.
#
# ### Simulate data
#
# Alternatively, we can simulate data for our train and validation datasets. The features will be tabular with `n_rows` and `n_columns` in the training dataset, where each value is either of type `np.float32` if the data is numerical or `np.uint8` if the data is categorical. Both numerical and categorical data can also be combined; for this experiment, we have ignored this combination.

# %%
import numpy as np
import pandas as pd


# helper function for simulating data
def simulate_data(m, n, k=2, numerical=False):
    if numerical:
        features = np.random.rand(m, n)
    else:
        features = np.random.randint(2, size=(m, n))
    labels = np.random.randint(k, size=m)
    return np.c_[labels, features].astype(np.float32)


# helper function for loading data
def load_data(filename, n_rows):
    if n_rows >= 1e9:
        df = pd.read_csv(filename)
    else:
        df = pd.read_csv(filename, nrows=n_rows)
    return df.values.astype(np.float32)

# %%
df = pd.read_csv('hisp_tier_sample.txt', delimiter="\t", header='infer',skip_blank_lines='True',engine='python')

# %%
print(df.shape)
# Out:
# (1045736, 301)

# %%
# settings
LOAD = False
n_gpus = 4
n_rows, n_columns = df.shape
n_categories = 2

# %%
df.columns
# Out:
# Index(['_u1.e_c_pct_hh_speakspanish', '_u1.r_cr_cust_sol_cnt',
#        '_u1.telesales_est_cntcts', '_u1.r_hispanic_acculturation',
#        '_u1.r_second_indv_age', '_u1.tts_past_past_ttl_tickets',
#        '_u1.sc_max_up_fec_uncorrect_l30d', '_u1.mrm_recurring_hsd_amt_10m',
#        '_u1.e_pcthh_fam_no_child_lt_18', '_u1.svcs_days_since_had_last_vid',
#        ...
#        '_u1.truckroll_tot_points_7d', '_u1.r_vid_mos_on_books_gap_18mo',
#        '_u1.vi_tbn_max_dvr', '_u1.eml_snt_strat_cust_l7d',
#        '_u1.r_vid_active_mos_on_books', '_u1.e_pct_wrst_stat_30',
#        '_u1.acct_prev_busunit_principal', '_u1.sc_avg_ds_receive_pwr_l3d',
#        '_u1.e_pct_pop_no_sch_age_3plus', '_u1.telesales_cntct_nm'],
#       dtype='object', length=301)

# %%
#remove the prefix from column names
df.rename(columns=lambda x: x[4:], inplace=True)

# %%
df.columns
# Out:
# Index(['e_c_pct_hh_speakspanish', 'r_cr_cust_sol_cnt', 'telesales_est_cntcts',
#        'r_hispanic_acculturation', 'r_second_indv_age',
#        'tts_past_past_ttl_tickets', 'sc_max_up_fec_uncorrect_l30d',
#        'mrm_recurring_hsd_amt_10m', 'e_pcthh_fam_no_child_lt_18',
#        'svcs_days_since_had_last_vid',
#        ...
#        'truckroll_tot_points_7d', 'r_vid_mos_on_books_gap_18mo',
#        'vi_tbn_max_dvr', 'eml_snt_strat_cust_l7d', 'r_vid_active_mos_on_books',
#        'e_pct_wrst_stat_30', 'acct_prev_busunit_principal',
#        'sc_avg_ds_receive_pwr_l3d', 'e_pct_pop_no_sch_age_3plus',
#        'telesales_cntct_nm'],
#       dtype='object', length=301)

# %%
df.head(10)
# Out:
#    e_c_pct_hh_speakspanish  r_cr_cust_sol_cnt  telesales_est_cntcts  \
# 0                     93.7                NaN                     0
# 1                     70.7                NaN                     0
# 2                     69.0                NaN                     0
# 3                      2.3                NaN                     0
# 4                      6.0                NaN                     0
# 5                      9.8                NaN                     0
# 6                     24.1                1.0                     0
# 7                      2.3                NaN                     0
# 8                      1.5                NaN                     0
# 9                     63.2                0.0                     0
#
#   r_hispanic_acculturation r_second_indv_age  tts_past_past_ttl_tickets  \
# 0                      HA5                 U                       32.0
# 1                      HA5                 U                       23.0
# 2                      NaN                53                       18.0
# 3                      NaN                 U                       17.0
# 4                      NaN                 U                       23.0
# 5                      NaN                77                       48.0
# 6                      NaN                 U                       23.0
# 7                      NaN                 U                       36.0
# 8                      NaN                55                       15.0
# 9                      HA3                 U                        4.0
#
#    sc_max_up_fec_uncorrect_l30d  mrm_recurring_hsd_amt_10m  \
# 0                          92.0                       6.71
# 1                           NaN                       0.00
# 2                        9940.0                      47.83
# 3                          81.0                        NaN
# 4                          94.0                        NaN
# 5                          98.0                      42.00
# 6                          94.0                      57.22
# 7                           NaN                       0.00
# 8                         413.0                        NaN
# 9                           9.0                      56.79
#
#    e_pcthh_fam_no_child_lt_18  svcs_days_since_had_last_vid  ...  \
# 0                        41.7                         483.0  ...
# 1                        34.0                         813.0  ...
# 2                        34.2                           NaN  ...
# 3                        42.8                           NaN  ...
# 4                        44.6                           NaN  ...
# 5                        34.3                           NaN  ...
# 6                        35.9                         322.0  ...
# 7                        25.3                         286.0  ...
# 8                        38.4                           NaN  ...
# 9                        35.9                           NaN  ...
#
#    truckroll_tot_points_7d  r_vid_mos_on_books_gap_18mo  vi_tbn_max_dvr  \
# 0                      0.0                          238             NaN
# 1                      0.0                           68             NaN
# 2                      0.0                           17             NaN
# 3                      0.0                            5             NaN
# 4                      NaN                            0             NaN
# 5                      0.0                           25             NaN
# 6                      0.0                           10             NaN
# 7                      NaN                           20             NaN
# 8                      0.0                           36             NaN
# 9                      0.0                           25             NaN
#
#    eml_snt_strat_cust_l7d r_vid_active_mos_on_books  e_pct_wrst_stat_30  \
# 0                     0.0                       238                58.0
# 1                     NaN                        68                67.0
# 2                     4.0                        17                36.0
# 3                     NaN                         5               100.0
# 4                     0.0                         0                53.0
# 5                     0.0                        25                50.0
# 6                     3.0                        10                68.0
# 7                     2.0                        20                56.0
# 8                     1.0                        36                57.0
# 9                     NaN                        25                56.0
#
#    acct_prev_busunit_principal  sc_avg_ds_receive_pwr_l3d  \
# 0                       6000.0                  -0.025000
# 1                       6000.0                        NaN
# 2                       6000.0                  -4.087500
# 3                       7400.0                   5.291667
# 4                       7400.0                  -4.683333
# 5                       7500.0                  -2.009524
# 6                       7500.0                  -3.363636
# 7                       2000.0                        NaN
# 8                       7000.0                  -1.886667
# 9                       9500.0                  -0.656522
#
#    e_pct_pop_no_sch_age_3plus telesales_cntct_nm
# 0                        78.8                NaN
# 1                        77.4                NaN
# 2                        86.5                NaN
# 3                        72.3                NaN
# 4                        66.7                NaN
# 5                        76.6                NaN
# 6                        77.2                NaN
# 7                        78.0                NaN
# 8                        70.1                NaN
# 9                        71.7                NaN
#
# [10 rows x 301 columns]

# %%
df.r_geo_hispanicity.value_counts()
# Out:
# HA3    35447
# HA2    35396
# HA1    12088
# HA4    10033
# HA5     5077
# Name: r_geo_hispanicity, dtype: int64

# %%
dataset = df[['r_first_indv_age', 'r_demo_first_indv_age',
       'nsd_demo_first_indv_age', 'vi_cine_max_totl',
       'e_c_child_age_7t9_s', 'e_c_child_age_4t6_s',
       'r_bill_pmt_cycle', 'vi_cine_max_lin_sum','r_geo_hispanicity',
       'vi_hispaniclinearmin','nsd_hispanic_tier_ind','r_spanish_bill','r_geo_hispanicity',
       'target']]
dataset.head(10)
# Out:
#   r_first_indv_age r_demo_first_indv_age nsd_demo_first_indv_age  \
# 0               48                    81                      81
# 1               57                    58                      71
# 2               53                    50                      50
# 3               45                    29                      29
# 4               45                    39                      39
# 5               75                    73                      25
# 6               33                    34                      34
# 7               58                    74                      74
# 8               61                    58                      46
# 9               51                    51                      53
#
#    vi_cine_max_totl  e_c_child_age_7t9_s  e_c_child_age_4t6_s  \
# 0               NaN                  5.0                 11.0
# 1               NaN                  2.0                  1.0
# 2               NaN                  2.0                  2.0
# 3               NaN                 16.0                 17.0
# 4               NaN                 14.0                 18.0
# 5               NaN                  1.0                  1.0
# 6               NaN                  5.0                  8.0
# 7               NaN                  1.0                  1.0
# 8               NaN                  1.0                  1.0
# 9               NaN                  0.0                  0.0
#
#    r_bill_pmt_cycle  vi_cine_max_lin_sum r_geo_hispanicity  \
# 0                12                  NaN               HA5
# 1                28                  NaN               HA5
# 2                 1                  NaN               NaN
# 3                20                  NaN               NaN
# 4                 1                  NaN               NaN
# 5                 2                  NaN               NaN
# 6                25                  NaN               NaN
# 7                 5                  NaN               NaN
# 8                23                  NaN               NaN
# 9                26                  NaN               HA3
#
#    vi_hispaniclinearmin  nsd_hispanic_tier_ind  r_spanish_bill  \
# 0                   NaN                    NaN             NaN
# 1                  8.64                    NaN             NaN
# 2                  8.42                    NaN             NaN
# 3                   NaN                    NaN             NaN
# 4                   NaN                    NaN             NaN
# 5                   NaN                    NaN             NaN
# 6                 32.92                    NaN             NaN
# 7                   NaN                    NaN             NaN
# 8                   NaN                    NaN             NaN
# 9                446.20                    NaN             NaN
#
#   r_geo_hispanicity  target
# 0               HA5       1
# 1               HA5       1
# 2               NaN       1
# 3               NaN       1
# 4               NaN       1
# 5               NaN       1
# 6               NaN       1
# 7               NaN       1
# 8               NaN       1
# 9               HA3       1

# %%
dataset = df[['r_first_indv_age', 'r_demo_first_indv_age',
       'nsd_demo_first_indv_age', 'vi_cine_max_totl',
       'e_c_child_age_7t9_s', 'e_c_child_age_4t6_s',
       'r_bill_pmt_cycle', 'vi_cine_max_lin_sum',
       'vi_hispaniclinearmin','nsd_hispanic_tier_ind','r_spanish_bill','r_geo_hispanicity',
       'target']]

# %%
dataset.columns
# Out:
# Index(['r_first_indv_age', 'r_demo_first_indv_age', 'nsd_demo_first_indv_age',
#        'vi_cine_max_totl', 'e_c_child_age_7t9_s', 'e_c_child_age_4t6_s',
#        'r_bill_pmt_cycle', 'vi_cine_max_lin_sum', 'vi_hispaniclinearmin',
#        'nsd_hispanic_tier_ind', 'r_spanish_bill', 'r_geo_hispanicity',
#        'target'],
#       dtype='object')

# %%
dataset = dataset.fillna(0)
dataset.head(10)
# Out:
#   r_first_indv_age r_demo_first_indv_age nsd_demo_first_indv_age  \
# 0               48                    81                      81
# 1               57                    58                      71
# 2               53                    50                      50
# 3               45                    29                      29
# 4               45                    39                      39
# 5               75                    73                      25
# 6               33                    34                      34
# 7               58                    74                      74
# 8               61                    58                      46
# 9               51                    51                      53
#
#    vi_cine_max_totl  e_c_child_age_7t9_s  e_c_child_age_4t6_s  \
# 0               0.0                  5.0                 11.0
# 1               0.0                  2.0                  1.0
# 2               0.0                  2.0                  2.0
# 3               0.0                 16.0                 17.0
# 4               0.0                 14.0                 18.0
# 5               0.0                  1.0                  1.0
# 6               0.0                  5.0                  8.0
# 7               0.0                  1.0                  1.0
# 8               0.0                  1.0                  1.0
# 9               0.0                  0.0                  0.0
#
#    r_bill_pmt_cycle  vi_cine_max_lin_sum  vi_hispaniclinearmin  \
# 0                12                  0.0                  0.00
# 1                28                  0.0                  8.64
# 2                 1                  0.0                  8.42
# 3                20                  0.0                  0.00
# 4                 1                  0.0                  0.00
# 5                 2                  0.0                  0.00
# 6                25                  0.0                 32.92
# 7                 5                  0.0                  0.00
# 8                23                  0.0                  0.00
# 9                26                  0.0                446.20
#
#    nsd_hispanic_tier_ind  r_spanish_bill r_geo_hispanicity  target
# 0                    0.0             0.0               HA5       1
# 1                    0.0             0.0               HA5       1
# 2                    0.0             0.0                 0       1
# 3                    0.0             0.0                 0       1
# 4                    0.0             0.0                 0       1
# 5                    0.0             0.0                 0       1
# 6                    0.0             0.0                 0       1
# 7                    0.0             0.0                 0       1
# 8                    0.0             0.0                 0       1
# 9                    0.0             0.0               HA3       1

# %%
dataset["r_first_indv_age"] = dataset.r_first_indv_age.replace("U", 50)
dataset["r_demo_first_indv_age"] = dataset.r_demo_first_indv_age.replace("U", 50)
dataset["nsd_demo_first_indv_age"] = dataset.nsd_demo_first_indv_age.replace("U", 50)
dataset["r_geo_hispanicity"] = dataset.r_geo_hispanicity.replace('HA1', 1)
dataset["r_geo_hispanicity"] = dataset.r_geo_hispanicity.replace('HA2', 2)
dataset["r_geo_hispanicity"] = dataset.r_geo_hispanicity.replace('HA3', 3)
dataset["r_geo_hispanicity"] = dataset.r_geo_hispanicity.replace('HA4', 4)
dataset["r_geo_hispanicity"] = dataset.r_geo_hispanicity.replace('HA5', 5)

# %%
dataset["r_first_indv_age"] = dataset.r_first_indv_age.astype(np.float32)
dataset["r_demo_first_indv_age"] = dataset.r_demo_first_indv_age.astype(np.float32)
dataset["nsd_demo_first_indv_age"] = dataset.nsd_demo_first_indv_age.astype(np.float32)
dataset["r_bill_pmt_cycle"] = dataset.r_bill_pmt_cycle.astype(np.float32)

# %%
dataset.head(10)
# Out:
#    r_first_indv_age  r_demo_first_indv_age  nsd_demo_first_indv_age  \
# 0              48.0                   81.0                     81.0
# 1              57.0                   58.0                     71.0
# 2              53.0                   50.0                     50.0
# 3              45.0                   29.0                     29.0
# 4              45.0                   39.0                     39.0
# 5              75.0                   73.0                     25.0
# 6              33.0                   34.0                     34.0
# 7              58.0                   74.0                     74.0
# 8              61.0                   58.0                     46.0
# 9              51.0                   51.0                     53.0
#
#    vi_cine_max_totl  e_c_child_age_7t9_s  e_c_child_age_4t6_s  \
# 0               0.0                  5.0                 11.0
# 1               0.0                  2.0                  1.0
# 2               0.0                  2.0                  2.0
# 3               0.0                 16.0                 17.0
# 4               0.0                 14.0                 18.0
# 5               0.0                  1.0                  1.0
# 6               0.0                  5.0                  8.0
# 7               0.0                  1.0                  1.0
# 8               0.0                  1.0                  1.0
# 9               0.0                  0.0                  0.0
#
#    r_bill_pmt_cycle  vi_cine_max_lin_sum  vi_hispaniclinearmin  \
# 0              12.0                  0.0                  0.00
# 1              28.0                  0.0                  8.64
# 2               1.0                  0.0                  8.42
# 3              20.0                  0.0                  0.00
# 4               1.0                  0.0                  0.00
# 5               2.0                  0.0                  0.00
# 6              25.0                  0.0                 32.92
# 7               5.0                  0.0                  0.00
# 8              23.0                  0.0                  0.00
# 9              26.0                  0.0                446.20
#
#    nsd_hispanic_tier_ind  r_spanish_bill  r_geo_hispanicity  target
# 0                    0.0             0.0                  5       1
# 1                    0.0             0.0                  5       1
# 2                    0.0             0.0                  0       1
# 3                    0.0             0.0                  0       1
# 4                    0.0             0.0                  0       1
# 5                    0.0             0.0                  0       1
# 6                    0.0             0.0                  0       1
# 7                    0.0             0.0                  0       1
# 8                    0.0             0.0                  0       1
# 9                    0.0             0.0                  3       1

# %%
dataset.dtypes
# Out:
# r_first_indv_age           float32
# r_demo_first_indv_age      float32
# nsd_demo_first_indv_age    float32
# vi_cine_max_totl           float64
# e_c_child_age_7t9_s        float64
# e_c_child_age_4t6_s        float64
# r_bill_pmt_cycle           float32
# vi_cine_max_lin_sum        float64
# vi_hispaniclinearmin       float64
# nsd_hispanic_tier_ind      float64
# r_spanish_bill             float64
# r_geo_hispanicity            int64
# target                       int64
# dtype: object

# %%
n_rows, n_columns = dataset.shape
train_size = 0.8

# %%
# split X, y
X, y  = dataset[['r_first_indv_age', 'r_demo_first_indv_age', 'nsd_demo_first_indv_age','vi_cine_max_totl', 
            'e_c_child_age_7t9_s', 'e_c_child_age_4t6_s','r_geo_hispanicity','vi_hispaniclinearmin',
                 'nsd_hispanic_tier_ind','r_spanish_bill',
                 'r_bill_pmt_cycle','vi_cine_max_lin_sum']] , dataset[['target']]

# %%
# split train data
X_train = X.sample(frac=train_size, replace=False, random_state=4)
y_train = y.sample(frac=train_size, replace=False, random_state=4)
train_index = X_train.index.values
#X_train, y_train = X[:train_index], y[:train_index]
X_train.count()
# Out:
# r_first_indv_age           836589
# r_demo_first_indv_age      836589
# nsd_demo_first_indv_age    836589
# vi_cine_max_totl           836589
# e_c_child_age_7t9_s        836589
# e_c_child_age_4t6_s        836589
# r_geo_hispanicity          836589
# vi_hispaniclinearmin       836589
# nsd_hispanic_tier_ind      836589
# r_spanish_bill             836589
# r_bill_pmt_cycle           836589
# vi_cine_max_lin_sum        836589
# dtype: int64

# %%
# split validation data
X_validation, y_validation = X.drop(train_index), y.drop(train_index)
X_validation.count()
# Out:
# r_first_indv_age           209147
# r_demo_first_indv_age      209147
# nsd_demo_first_indv_age    209147
# vi_cine_max_totl           209147
# e_c_child_age_7t9_s        209147
# e_c_child_age_4t6_s        209147
# r_geo_hispanicity          209147
# vi_hispaniclinearmin       209147
# nsd_hispanic_tier_ind      209147
# r_spanish_bill             209147
# r_bill_pmt_cycle           209147
# vi_cine_max_lin_sum        209147
# dtype: int64

# %%
y_train.target.value_counts()
# Out:
# 0    799972
# 1     36617
# Name: target, dtype: int64

# %%
y_validation.target.value_counts()
# Out:
# 0    200028
# 1      9119
# Name: target, dtype: int64

# %%
# %%time

if LOAD:
    dataset = load_data('hisp_tier.txt', n_rows )
else:
    dataset = simulate_data(n_rows, n_columns, n_categories)
print(dataset.shape)
# Out:
# (1045736, 14)
# CPU times: user 147 ms, sys: 0 ns, total: 147 ms
# Wall time: 145 ms

# %% [markdown]
# ### Split data for simulated ones here
#
# We'll split our dataset into a 80% training dataset and a 20% validation dataset.

# %%
# identify shape and indices
n_rows, n_columns = dataset.shape
train_size = 0.80
train_index = int(n_rows * train_size)

# split X, y
X, y = dataset[:, 1:], dataset[:, 0]
#del dataset

# split train data
X_train, y_train = X[:train_index, :], y[:train_index]

# split validation data
X_validation, y_validation = X[train_index:, :], y[train_index:]

# %% [markdown]
# ### Check dimensions
#
# We can check the dimensions and proportions of our training and validation dataets.

# %%
# print(X_train[:3, :], y_train[:3])

# %%
# check dimensions
print('X_train: ', X_train.shape, X_train.dtypes, 'y_train: ', y_train.shape, y_train.dtypes)
print('X_validation', X_validation.shape, X_validation.dtypes, 'y_validation: ', y_validation.shape, y_validation.dtypes)

# check the proportions
total = X_train.shape[0] + X_validation.shape[0]
print('X_train proportion:', X_train.shape[0] / total)
print('X_validation proportion:', X_validation.shape[0] / total)
# Out:
# X_train:  (836589, 12) r_first_indv_age           float32
# r_demo_first_indv_age      float32
# nsd_demo_first_indv_age    float32
# vi_cine_max_totl           float64
# e_c_child_age_7t9_s        float64
# e_c_child_age_4t6_s        float64
# r_geo_hispanicity            int64
# vi_hispaniclinearmin       float64
# nsd_hispanic_tier_ind      float64
# r_spanish_bill             float64
# r_bill_pmt_cycle           float32
# vi_cine_max_lin_sum        float64
# dtype: object y_train:  (836589, 1) target    int64
# dtype: object
# X_validation (209147, 12) r_first_indv_age           float32
# r_demo_first_indv_age      float32
# nsd_demo_first_indv_age    float32
# vi_cine_max_totl           float64
# e_c_child_age_7t9_s        float64
# e_c_child_age_4t6_s        float64
# r_geo_hispanicity            int64
# vi_hispaniclinearmin       float64
# nsd_hispanic_tier_ind      float64
# r_spanish_bill             float64
# r_bill_pmt_cycle           float32
# vi_cine_max_lin_sum        float64
# dtype: object y_validation:  (209147, 1) target    int64
# dtype: object
# X_train proportion: 0.8000001912528593
# X_validation proportion: 0.19999980874714077

# %% [markdown]
# ## Convert NumPy data to DMatrix format
#
# With out data simulated and formatted as NumPy arrays, our next step is to convert this to a `DMatrix` object that XGBoost can work with. We can instantiate an object of the `xgboost.DMatrix` by passing in the feature matrix as the first argument followed by the label vector using the `label=` keyword argument. To learn more about XGBoost's support for data structures other than NumPy arrays, see the documentation for the Data Interface:
#
#
# https://xgboost.readthedocs.io/en/latest/python/python_intro.html#data-interface

# %%
# %%time

import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train)
dvalidation = xgb.DMatrix(X_validation, label=y_validation)
# Out:
# CPU times: user 143 ms, sys: 197 µs, total: 144 ms
# Wall time: 142 ms

# %% [markdown]
# ## Set parameters
#
# There are a number of parameters that can be set before XGBoost can be run.
#
# * General parameters relate to which booster we are using to do boosting, commonly tree or linear model
# * Booster parameters depend on which booster you have chosen
# * Learning task parameters decide on the learning scenario. For example, regression tasks may use different parameters with ranking tasks.
#
# For more information on the configurable parameters within the XGBoost module, see the documentation here:
#
#
# https://xgboost.readthedocs.io/en/latest/parameter.html

# %%
# instantiate params
params = {}

# general params
general_params = {'silent': 1}
params.update(general_params)

# booster params
# n_gpus = 0
booster_params = {'max_depth': 3,'eta':0.06}

if n_gpus != 0:
    booster_params['tree_method'] = 'gpu_hist'
    booster_params['n_gpus'] = n_gpus
params.update(booster_params)

# learning task params
learning_task_params = {'eval_metric': 'auc', 'objective': 'binary:logistic'}
params.update(learning_task_params)
print(params)
# Out:
# {'silent': 1, 'max_depth': 3, 'eta': 0.06, 'tree_method': 'gpu_hist', 'n_gpus': 4, 'eval_metric': 'auc', 'objective': 'binary:logistic'}

# %% [markdown]
# ## Train model
#
# Now it's time to train our model! We can use the `xgb.train` function and pass in the parameters, training dataset, the number of boosting iterations, and the list of items to be evaluated during training. For more information on the parameters that can be passed into `xgb.train`, check out the documentation:
#
#
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.train

# %%
# model training settings
evallist = [(dvalidation, 'validation'), (dtrain, 'train')]
num_round = 10000

# %%
# %%time

bst = xgb.train(params, dtrain, num_round, evallist)
# Out:
# [0]	validation-auc:0.629269	train-auc:0.626114
# [1]	validation-auc:0.629257	train-auc:0.626135
# [2]	validation-auc:0.629399	train-auc:0.626583
# [3]	validation-auc:0.629406	train-auc:0.626594
# [4]	validation-auc:0.629409	train-auc:0.626598
# [5]	validation-auc:0.630113	train-auc:0.627165
# [6]	validation-auc:0.630112	train-auc:0.627165
# [7]	validation-auc:0.630137	train-auc:0.627198
# [8]	validation-auc:0.630124	train-auc:0.627178
# [9]	validation-auc:0.633761	train-auc:0.630758
# [10]	validation-auc:0.633873	train-auc:0.630893
# [11]	validation-auc:0.633873	train-auc:0.630897
# [12]	validation-auc:0.63401	train-auc:0.631017
# [13]	validation-auc:0.666803	train-auc:0.663339
# [14]	validation-auc:0.666802	train-auc:0.663339
# [15]	validation-auc:0.666813	train-auc:0.663354
# [16]	validation-auc:0.666805	train-auc:0.663342
# [17]	validation-auc:0.66738	train-auc:0.663697
# [18]	validation-auc:0.667486	train-auc:0.663803
# [19]	validation-auc:0.667488	train-auc:0.663816
# [20]	validation-auc:0.667512	train-auc:0.663831
# [21]	validation-auc:0.668743	train-auc:0.664996
# [22]	validation-auc:0.66873	train-auc:0.665019
# [23]	validation-auc:0.669249	train-auc:0.665383
# [24]	validation-auc:0.66999	train-auc:0.666114
# [25]	validation-auc:0.670015	train-auc:0.666144
# [26]	validation-auc:0.66982	train-auc:0.66632
# [27]	validation-auc:0.669823	train-auc:0.666322
# [28]	validation-auc:0.669579	train-auc:0.666168
# [29]	validation-auc:0.669851	train-auc:0.666353
# [30]	validation-auc:0.669853	train-auc:0.666351
# [31]	validation-auc:0.670102	train-auc:0.667046
# [32]	validation-auc:0.669885	train-auc:0.666926
# [33]	validation-auc:0.669932	train-auc:0.66701
# [34]	validation-auc:0.66993	train-auc:0.667006
# [35]	validation-auc:0.670148	train-auc:0.667193
# [36]	validation-auc:0.670147	train-auc:0.66719
# [37]	validation-auc:0.676745	train-auc:0.674615
# [38]	validation-auc:0.67674	train-auc:0.6746
# [39]	validation-auc:0.676678	train-auc:0.674658
# [40]	validation-auc:0.67669	train-auc:0.67466
# [41]	validation-auc:0.677056	train-auc:0.674877
# [42]	validation-auc:0.67707	train-auc:0.674892
# [43]	validation-auc:0.677111	train-auc:0.67497
# [44]	validation-auc:0.677224	train-auc:0.674962
# [45]	validation-auc:0.677094	train-auc:0.674958
# [46]	validation-auc:0.677109	train-auc:0.674951
# [47]	validation-auc:0.677109	train-auc:0.674966
# [48]	validation-auc:0.67731	train-auc:0.675195
# [49]	validation-auc:0.677412	train-auc:0.675264
# [50]	validation-auc:0.677409	train-auc:0.675266
# [51]	validation-auc:0.677416	train-auc:0.675288
# [52]	validation-auc:0.67741	train-auc:0.675285
# [53]	validation-auc:0.677397	train-auc:0.675268
# [54]	validation-auc:0.682559	train-auc:0.679482
# [55]	validation-auc:0.682578	train-auc:0.679493
# [56]	validation-auc:0.68263	train-auc:0.67963
# [57]	validation-auc:0.682955	train-auc:0.680107
# [58]	validation-auc:0.683049	train-auc:0.680141
# [59]	validation-auc:0.683189	train-auc:0.680174
# [60]	validation-auc:0.683342	train-auc:0.680327
# [61]	validation-auc:0.684359	train-auc:0.68097
# [62]	validation-auc:0.684379	train-auc:0.681116
# [63]	validation-auc:0.684392	train-auc:0.681138
# [64]	validation-auc:0.684371	train-auc:0.681253
# [65]	validation-auc:0.684507	train-auc:0.681383
# [66]	validation-auc:0.684496	train-auc:0.681405
# [67]	validation-auc:0.684695	train-auc:0.681474
# [68]	validation-auc:0.684679	train-auc:0.681477
# [69]	validation-auc:0.684842	train-auc:0.681567
# [70]	validation-auc:0.685132	train-auc:0.681737
# [71]	validation-auc:0.685363	train-auc:0.681934
# [72]	validation-auc:0.685385	train-auc:0.68195
# [73]	validation-auc:0.685537	train-auc:0.681937
# [74]	validation-auc:0.685551	train-auc:0.681932
# [75]	validation-auc:0.685766	train-auc:0.682001
# [76]	validation-auc:0.685798	train-auc:0.682099
# [77]	validation-auc:0.68594	train-auc:0.682265
# [78]	validation-auc:0.686042	train-auc:0.682326
# [79]	validation-auc:0.686005	train-auc:0.68244
# [80]	validation-auc:0.68656	train-auc:0.682703
# [81]	validation-auc:0.686584	train-auc:0.68278
# [82]	validation-auc:0.686795	train-auc:0.682875
# [83]	validation-auc:0.687095	train-auc:0.683186
# [84]	validation-auc:0.687136	train-auc:0.683209
# [85]	validation-auc:0.687291	train-auc:0.683391
# [86]	validation-auc:0.687295	train-auc:0.683389
# [87]	validation-auc:0.687301	train-auc:0.683558
# [88]	validation-auc:0.687277	train-auc:0.683575
# [89]	validation-auc:0.68731	train-auc:0.683612
# [90]	validation-auc:0.687409	train-auc:0.683727
# [91]	validation-auc:0.687709	train-auc:0.68399
# [92]	validation-auc:0.68785	train-auc:0.68403
# [93]	validation-auc:0.68779	train-auc:0.684109
# [94]	validation-auc:0.687901	train-auc:0.684162
# [95]	validation-auc:0.688081	train-auc:0.684206
# [96]	validation-auc:0.688076	train-auc:0.6843
# [97]	validation-auc:0.688079	train-auc:0.684303
# [98]	validation-auc:0.688066	train-auc:0.684359
# [99]	validation-auc:0.688062	train-auc:0.684366
# [100]	validation-auc:0.68807	train-auc:0.68451
# [101]	validation-auc:0.688057	train-auc:0.684595
# [102]	validation-auc:0.688239	train-auc:0.684796
# [103]	validation-auc:0.688281	train-auc:0.684847
# [104]	validation-auc:0.688317	train-auc:0.684905
# [105]	validation-auc:0.688338	train-auc:0.684911
# [106]	validation-auc:0.688282	train-auc:0.68508
# [107]	validation-auc:0.688294	train-auc:0.685174
# [108]	validation-auc:0.688251	train-auc:0.685208
# [109]	validation-auc:0.688254	train-auc:0.685209
# [110]	validation-auc:0.688261	train-auc:0.685342
# [111]	validation-auc:0.688309	train-auc:0.685413
# [112]	validation-auc:0.688375	train-auc:0.685561
# [113]	validation-auc:0.68838	train-auc:0.685582
# [114]	validation-auc:0.688423	train-auc:0.685696
# [115]	validation-auc:0.688481	train-auc:0.685885
# [116]	validation-auc:0.688488	train-auc:0.685897
# [117]	validation-auc:0.68849	train-auc:0.685898
# [118]	validation-auc:0.688769	train-auc:0.686177
# [119]	validation-auc:0.688789	train-auc:0.686219
# [120]	validation-auc:0.688854	train-auc:0.686349
# [121]	validation-auc:0.68886	train-auc:0.68636
# [122]	validation-auc:0.688973	train-auc:0.686522
# [123]	validation-auc:0.689019	train-auc:0.68661
# [124]	validation-auc:0.689138	train-auc:0.686732
# [125]	validation-auc:0.689152	train-auc:0.686882
# [126]	validation-auc:0.6892	train-auc:0.687
# [127]	validation-auc:0.689276	train-auc:0.686998
# [128]	validation-auc:0.689279	train-auc:0.687
# [129]	validation-auc:0.689288	train-auc:0.687013
# [130]	validation-auc:0.689211	train-auc:0.687107
# [131]	validation-auc:0.689405	train-auc:0.687274
# [132]	validation-auc:0.68966	train-auc:0.687427
# [133]	validation-auc:0.689654	train-auc:0.687422
# [134]	validation-auc:0.689635	train-auc:0.687503
# [135]	validation-auc:0.689656	train-auc:0.687532
# [136]	validation-auc:0.689695	train-auc:0.687604
# [137]	validation-auc:0.689681	train-auc:0.687638
# [138]	validation-auc:0.689797	train-auc:0.687729
# [139]	validation-auc:0.689848	train-auc:0.687769
# [140]	validation-auc:0.690032	train-auc:0.687953
# [141]	validation-auc:0.690034	train-auc:0.687984
# [142]	validation-auc:0.690029	train-auc:0.687991
# [143]	validation-auc:0.690042	train-auc:0.688088
# [144]	validation-auc:0.690015	train-auc:0.688131
# [145]	validation-auc:0.690107	train-auc:0.688183
# [146]	validation-auc:0.690315	train-auc:0.688285
# [147]	validation-auc:0.690316	train-auc:0.688287
# [148]	validation-auc:0.690299	train-auc:0.68831
# [149]	validation-auc:0.69036	train-auc:0.688387
# [150]	validation-auc:0.690351	train-auc:0.68841
# [151]	validation-auc:0.690376	train-auc:0.688543
# [152]	validation-auc:0.690517	train-auc:0.688708
# [153]	validation-auc:0.690508	train-auc:0.688725
# [154]	validation-auc:0.690485	train-auc:0.688763
# [155]	validation-auc:0.690472	train-auc:0.688782
# [156]	validation-auc:0.690531	train-auc:0.688821
# [157]	validation-auc:0.69052	train-auc:0.688856
# [158]	validation-auc:0.690643	train-auc:0.688921
# [159]	validation-auc:0.690675	train-auc:0.689041
# [160]	validation-auc:0.690675	train-auc:0.689121
# [161]	validation-auc:0.690644	train-auc:0.689155
# [162]	validation-auc:0.690745	train-auc:0.689289
# [163]	validation-auc:0.690786	train-auc:0.689299
# [164]	validation-auc:0.6908	train-auc:0.689325
# [165]	validation-auc:0.690774	train-auc:0.689361
# [166]	validation-auc:0.690898	train-auc:0.689428
# [167]	validation-auc:0.690923	train-auc:0.689524
# [168]	validation-auc:0.691024	train-auc:0.689656
# [169]	validation-auc:0.691043	train-auc:0.689682
# [170]	validation-auc:0.691065	train-auc:0.689726
# [171]	validation-auc:0.691084	train-auc:0.68979
# [172]	validation-auc:0.691086	train-auc:0.689791
# [173]	validation-auc:0.69116	train-auc:0.689865
# [174]	validation-auc:0.691153	train-auc:0.68987
# [175]	validation-auc:0.691158	train-auc:0.689932
# [176]	validation-auc:0.691135	train-auc:0.689986
# [177]	validation-auc:0.691206	train-auc:0.690016
# [178]	validation-auc:0.691202	train-auc:0.69007
# [179]	validation-auc:0.691171	train-auc:0.690159
# [180]	validation-auc:0.691172	train-auc:0.69016
# [181]	validation-auc:0.691172	train-auc:0.690161
# [182]	validation-auc:0.691185	train-auc:0.690204
# [183]	validation-auc:0.691195	train-auc:0.690248
# [184]	validation-auc:0.691203	train-auc:0.690266
# [185]	validation-auc:0.691183	train-auc:0.690333
# [186]	validation-auc:0.691164	train-auc:0.690345
# [187]	validation-auc:0.691136	train-auc:0.690364
# [188]	validation-auc:0.69116	train-auc:0.690422
# [189]	validation-auc:0.691241	train-auc:0.69049
# [190]	validation-auc:0.691248	train-auc:0.690559
# [191]	validation-auc:0.691311	train-auc:0.690606
# [192]	validation-auc:0.691403	train-auc:0.690643
# [193]	validation-auc:0.691438	train-auc:0.690686
# [194]	validation-auc:0.691459	train-auc:0.690687
# [195]	validation-auc:0.691495	train-auc:0.690756
# [196]	validation-auc:0.691547	train-auc:0.690798
# [197]	validation-auc:0.691568	train-auc:0.69087
# [198]	validation-auc:0.691536	train-auc:0.690887
# [199]	validation-auc:0.691553	train-auc:0.690923
# [200]	validation-auc:0.691554	train-auc:0.690929
# [201]	validation-auc:0.69157	train-auc:0.690965
# [202]	validation-auc:0.691563	train-auc:0.691031
# [203]	validation-auc:0.69156	train-auc:0.691031
# [204]	validation-auc:0.691573	train-auc:0.691083
# [205]	validation-auc:0.691585	train-auc:0.691108
# [206]	validation-auc:0.691593	train-auc:0.691139
# [207]	validation-auc:0.691587	train-auc:0.691186
# [208]	validation-auc:0.691617	train-auc:0.691218
# [209]	validation-auc:0.691642	train-auc:0.691251
# [210]	validation-auc:0.691666	train-auc:0.691293
# [211]	validation-auc:0.691655	train-auc:0.691297
# [212]	validation-auc:0.691685	train-auc:0.691307
# [213]	validation-auc:0.691651	train-auc:0.691347
# [214]	validation-auc:0.691632	train-auc:0.691381
# [215]	validation-auc:0.691669	train-auc:0.691404
# [216]	validation-auc:0.691666	train-auc:0.691407
# [217]	validation-auc:0.691724	train-auc:0.691443
# [218]	validation-auc:0.69173	train-auc:0.691489
# [219]	validation-auc:0.691713	train-auc:0.691539
# [220]	validation-auc:0.691728	train-auc:0.69156
# [221]	validation-auc:0.691728	train-auc:0.691561
# [222]	validation-auc:0.691701	train-auc:0.691602
# [223]	validation-auc:0.691728	train-auc:0.691633
# [224]	validation-auc:0.691727	train-auc:0.691634
# [225]	validation-auc:0.691728	train-auc:0.691685
# [226]	validation-auc:0.6917	train-auc:0.691745
# [227]	validation-auc:0.691736	train-auc:0.691788
# [228]	validation-auc:0.691756	train-auc:0.691827
# [229]	validation-auc:0.691877	train-auc:0.691886
# [230]	validation-auc:0.691896	train-auc:0.691908
# [231]	validation-auc:0.691945	train-auc:0.691941
# [232]	validation-auc:0.691997	train-auc:0.692
# [233]	validation-auc:0.691997	train-auc:0.692002
# [234]	validation-auc:0.692005	train-auc:0.692014
# [235]	validation-auc:0.691993	train-auc:0.692039
# [236]	validation-auc:0.691982	train-auc:0.692049
# [237]	validation-auc:0.691938	train-auc:0.692092
# [238]	validation-auc:0.692035	train-auc:0.692139
# [239]	validation-auc:0.692012	train-auc:0.692172
# [240]	validation-auc:0.692012	train-auc:0.692179
# [241]	validation-auc:0.692009	train-auc:0.692217
# [242]	validation-auc:0.691994	train-auc:0.692253
# [243]	validation-auc:0.692122	train-auc:0.6923
# [244]	validation-auc:0.692111	train-auc:0.69233
# [245]	validation-auc:0.692118	train-auc:0.692357
# [246]	validation-auc:0.692106	train-auc:0.692382
# [247]	validation-auc:0.692129	train-auc:0.692417
# [248]	validation-auc:0.692161	train-auc:0.69246
# [249]	validation-auc:0.692173	train-auc:0.692506
# [250]	validation-auc:0.692167	train-auc:0.69255
# [251]	validation-auc:0.692184	train-auc:0.692576
# [252]	validation-auc:0.69218	train-auc:0.692578
# [253]	validation-auc:0.692185	train-auc:0.692586
# [254]	validation-auc:0.692183	train-auc:0.692588
# [255]	validation-auc:0.692169	train-auc:0.692603
# [256]	validation-auc:0.692165	train-auc:0.692617
# [257]	validation-auc:0.69214	train-auc:0.692646
# [258]	validation-auc:0.69213	train-auc:0.692668
# [259]	validation-auc:0.692109	train-auc:0.692677
# [260]	validation-auc:0.692112	train-auc:0.692704
# [261]	validation-auc:0.692099	train-auc:0.692737
# [262]	validation-auc:0.692123	train-auc:0.692751
# [263]	validation-auc:0.692122	train-auc:0.692779
# [264]	validation-auc:0.692156	train-auc:0.69283
# [265]	validation-auc:0.692188	train-auc:0.692852
# [266]	validation-auc:0.692194	train-auc:0.692874
# [267]	validation-auc:0.692196	train-auc:0.692909
# [268]	validation-auc:0.692193	train-auc:0.692932
# [269]	validation-auc:0.692222	train-auc:0.692971
# [270]	validation-auc:0.692183	train-auc:0.692998
# [271]	validation-auc:0.692185	train-auc:0.692999
# [272]	validation-auc:0.692186	train-auc:0.693
# [273]	validation-auc:0.692183	train-auc:0.693001
# [274]	validation-auc:0.692225	train-auc:0.693038
# [275]	validation-auc:0.692226	train-auc:0.693038
# [276]	validation-auc:0.692227	train-auc:0.69304
# [277]	validation-auc:0.69223	train-auc:0.693076
# [278]	validation-auc:0.692244	train-auc:0.693114
# [279]	validation-auc:0.692247	train-auc:0.693117
# [280]	validation-auc:0.692254	train-auc:0.693125
# [281]	validation-auc:0.692315	train-auc:0.693161
# [282]	validation-auc:0.692331	train-auc:0.693162
# [283]	validation-auc:0.692338	train-auc:0.693175
# [284]	validation-auc:0.692382	train-auc:0.693217
# [285]	validation-auc:0.692386	train-auc:0.693237
# [286]	validation-auc:0.692402	train-auc:0.693244
# [287]	validation-auc:0.692401	train-auc:0.693247
# [288]	validation-auc:0.692404	train-auc:0.693266
# [289]	validation-auc:0.692401	train-auc:0.693275
# [290]	validation-auc:0.692397	train-auc:0.69329
# [291]	validation-auc:0.692417	train-auc:0.693315
# [292]	validation-auc:0.692417	train-auc:0.693316
# [293]	validation-auc:0.692427	train-auc:0.693323
# [294]	validation-auc:0.692437	train-auc:0.693328
# [295]	validation-auc:0.692423	train-auc:0.693351
# [296]	validation-auc:0.69241	train-auc:0.693371
# [297]	validation-auc:0.692411	train-auc:0.693372
# [298]	validation-auc:0.692412	train-auc:0.693373
# [299]	validation-auc:0.69242	train-auc:0.693375
# [300]	validation-auc:0.692417	train-auc:0.693382
# [301]	validation-auc:0.692441	train-auc:0.693416
# [302]	validation-auc:0.692489	train-auc:0.693479
# [303]	validation-auc:0.692489	train-auc:0.69348
# [304]	validation-auc:0.69249	train-auc:0.693481
# [305]	validation-auc:0.692496	train-auc:0.693498
# [306]	validation-auc:0.692522	train-auc:0.693542
# [307]	validation-auc:0.692528	train-auc:0.693566
# [308]	validation-auc:0.692533	train-auc:0.69357
# [309]	validation-auc:0.692534	train-auc:0.693571
# [310]	validation-auc:0.692535	train-auc:0.693572
# [311]	validation-auc:0.692538	train-auc:0.693613
# [312]	validation-auc:0.692515	train-auc:0.693634
# [313]	validation-auc:0.692509	train-auc:0.693661
# [314]	validation-auc:0.692493	train-auc:0.69367
# [315]	validation-auc:0.692515	train-auc:0.6937
# [316]	validation-auc:0.692505	train-auc:0.69372
# [317]	validation-auc:0.69251	train-auc:0.693742
# [318]	validation-auc:0.692505	train-auc:0.693745
# [319]	validation-auc:0.692506	train-auc:0.693745
# [320]	validation-auc:0.692517	train-auc:0.693781
# [321]	validation-auc:0.692517	train-auc:0.693783
# [322]	validation-auc:0.692497	train-auc:0.693808
# [323]	validation-auc:0.692506	train-auc:0.693804
# [324]	validation-auc:0.69252	train-auc:0.693819
# [325]	validation-auc:0.692558	train-auc:0.693868
# [326]	validation-auc:0.692571	train-auc:0.69389
# [327]	validation-auc:0.692554	train-auc:0.693894
# [328]	validation-auc:0.692561	train-auc:0.69391
# [329]	validation-auc:0.692597	train-auc:0.693942
# [330]	validation-auc:0.692601	train-auc:0.693962
# [331]	validation-auc:0.692588	train-auc:0.693987
# [332]	validation-auc:0.692604	train-auc:0.694003
# [333]	validation-auc:0.692601	train-auc:0.694017
# [334]	validation-auc:0.692608	train-auc:0.69403
# [335]	validation-auc:0.692602	train-auc:0.694031
# [336]	validation-auc:0.69264	train-auc:0.694068
# [337]	validation-auc:0.692729	train-auc:0.694127
# [338]	validation-auc:0.69273	train-auc:0.694138
# [339]	validation-auc:0.692738	train-auc:0.694176
# [340]	validation-auc:0.692746	train-auc:0.694188
# [341]	validation-auc:0.692808	train-auc:0.694222
# [342]	validation-auc:0.692825	train-auc:0.694246
# [343]	validation-auc:0.692821	train-auc:0.694249
# [344]	validation-auc:0.692807	train-auc:0.69427
# [345]	validation-auc:0.692787	train-auc:0.694299
# [346]	validation-auc:0.692788	train-auc:0.694324
# [347]	validation-auc:0.692801	train-auc:0.694328
# [348]	validation-auc:0.692802	train-auc:0.694339
# [349]	validation-auc:0.69283	train-auc:0.694365
# [350]	validation-auc:0.692815	train-auc:0.694397
# [351]	validation-auc:0.692814	train-auc:0.69445
# [352]	validation-auc:0.692827	train-auc:0.694475
# [353]	validation-auc:0.692828	train-auc:0.694511
# [354]	validation-auc:0.692826	train-auc:0.694528
# [355]	validation-auc:0.69283	train-auc:0.694542
# [356]	validation-auc:0.692831	train-auc:0.694543
# [357]	validation-auc:0.692804	train-auc:0.694558
# [358]	validation-auc:0.692804	train-auc:0.694559
# [359]	validation-auc:0.692801	train-auc:0.694563
# [360]	validation-auc:0.69282	train-auc:0.694593
# [361]	validation-auc:0.692823	train-auc:0.694605
# [362]	validation-auc:0.692824	train-auc:0.69462
# [363]	validation-auc:0.69281	train-auc:0.694624
# [364]	validation-auc:0.692808	train-auc:0.694631
# [365]	validation-auc:0.692808	train-auc:0.694653
# [366]	validation-auc:0.692808	train-auc:0.694653
# [367]	validation-auc:0.692823	train-auc:0.694674
# [368]	validation-auc:0.692827	train-auc:0.694677
# [369]	validation-auc:0.692842	train-auc:0.694686
# [370]	validation-auc:0.692849	train-auc:0.694691
# [371]	validation-auc:0.692845	train-auc:0.694693
# [372]	validation-auc:0.692862	train-auc:0.694716
# [373]	validation-auc:0.692944	train-auc:0.694769
# [374]	validation-auc:0.692944	train-auc:0.694785
# [375]	validation-auc:0.692975	train-auc:0.694802
# [376]	validation-auc:0.692937	train-auc:0.694827
# [377]	validation-auc:0.692929	train-auc:0.694837
# [378]	validation-auc:0.692929	train-auc:0.694838
# [379]	validation-auc:0.692973	train-auc:0.694862
# [380]	validation-auc:0.692986	train-auc:0.694884
# [381]	validation-auc:0.692966	train-auc:0.6949
# [382]	validation-auc:0.692991	train-auc:0.694915
# [383]	validation-auc:0.692987	train-auc:0.694934
# [384]	validation-auc:0.692991	train-auc:0.694957
# [385]	validation-auc:0.692991	train-auc:0.694957
# [386]	validation-auc:0.69303	train-auc:0.694979
# [387]	validation-auc:0.693033	train-auc:0.695002
# [388]	validation-auc:0.693035	train-auc:0.695011
# [389]	validation-auc:0.693023	train-auc:0.695023
# [390]	validation-auc:0.693019	train-auc:0.695026
# [391]	validation-auc:0.692995	train-auc:0.695058
# [392]	validation-auc:0.692979	train-auc:0.695079
# [393]	validation-auc:0.692989	train-auc:0.695098
# [394]	validation-auc:0.692987	train-auc:0.695113
# [395]	validation-auc:0.692998	train-auc:0.695121
# [396]	validation-auc:0.693011	train-auc:0.695155
# [397]	validation-auc:0.693004	train-auc:0.695168
# [398]	validation-auc:0.693003	train-auc:0.695169
# [399]	validation-auc:0.693003	train-auc:0.695169
# [400]	validation-auc:0.69299	train-auc:0.695182
# [401]	validation-auc:0.692994	train-auc:0.695188
# [402]	validation-auc:0.692996	train-auc:0.695187
# [403]	validation-auc:0.692994	train-auc:0.695213
# [404]	validation-auc:0.693003	train-auc:0.695244
# [405]	validation-auc:0.693015	train-auc:0.695272
# [406]	validation-auc:0.693011	train-auc:0.69528
# [407]	validation-auc:0.693029	train-auc:0.695298
# [408]	validation-auc:0.693029	train-auc:0.695298
# [409]	validation-auc:0.69303	train-auc:0.695307
# [410]	validation-auc:0.693025	train-auc:0.695325
# [411]	validation-auc:0.69303	train-auc:0.695338
# [412]	validation-auc:0.693026	train-auc:0.695346
# [413]	validation-auc:0.693016	train-auc:0.695369
# [414]	validation-auc:0.693032	train-auc:0.695392
# [415]	validation-auc:0.692993	train-auc:0.695415
# [416]	validation-auc:0.69299	train-auc:0.695418
# [417]	validation-auc:0.693018	train-auc:0.69545
# [418]	validation-auc:0.693042	train-auc:0.69547
# [419]	validation-auc:0.693049	train-auc:0.695477
# [420]	validation-auc:0.693044	train-auc:0.695498
# [421]	validation-auc:0.693044	train-auc:0.695498
# [422]	validation-auc:0.693059	train-auc:0.695504
# [423]	validation-auc:0.693059	train-auc:0.695505
# [424]	validation-auc:0.693059	train-auc:0.695505
# [425]	validation-auc:0.693071	train-auc:0.695526
# [426]	validation-auc:0.693063	train-auc:0.695549
# [427]	validation-auc:0.69308	train-auc:0.695559
# [428]	validation-auc:0.693075	train-auc:0.69558
# [429]	validation-auc:0.693069	train-auc:0.695599
# [430]	validation-auc:0.693085	train-auc:0.695628
# [431]	validation-auc:0.693082	train-auc:0.695635
# [432]	validation-auc:0.693078	train-auc:0.695649
# [433]	validation-auc:0.693058	train-auc:0.695657
# [434]	validation-auc:0.693046	train-auc:0.695666
# [435]	validation-auc:0.693065	train-auc:0.695681
# [436]	validation-auc:0.693063	train-auc:0.695684
# [437]	validation-auc:0.693069	train-auc:0.6957
# [438]	validation-auc:0.693069	train-auc:0.6957
# [439]	validation-auc:0.69306	train-auc:0.695705
# [440]	validation-auc:0.693041	train-auc:0.695753
# [441]	validation-auc:0.693042	train-auc:0.695772
# [442]	validation-auc:0.693042	train-auc:0.695793
# [443]	validation-auc:0.693022	train-auc:0.695798
# [444]	validation-auc:0.692999	train-auc:0.695838
# [445]	validation-auc:0.692996	train-auc:0.695843
# [446]	validation-auc:0.692998	train-auc:0.69588
# [447]	validation-auc:0.692995	train-auc:0.695886
# [448]	validation-auc:0.693038	train-auc:0.695913
# [449]	validation-auc:0.693085	train-auc:0.695968
# [450]	validation-auc:0.693087	train-auc:0.695977
# [451]	validation-auc:0.693088	train-auc:0.695985
# [452]	validation-auc:0.693095	train-auc:0.696001
# [453]	validation-auc:0.693093	train-auc:0.696026
# [454]	validation-auc:0.693138	train-auc:0.696056
# [455]	validation-auc:0.693175	train-auc:0.696082
# [456]	validation-auc:0.693172	train-auc:0.696086
# [457]	validation-auc:0.693225	train-auc:0.696117
# [458]	validation-auc:0.693218	train-auc:0.696123
# [459]	validation-auc:0.693218	train-auc:0.696149
# [460]	validation-auc:0.693215	train-auc:0.696155
# [461]	validation-auc:0.693219	train-auc:0.696189
# [462]	validation-auc:0.693204	train-auc:0.696228
# [463]	validation-auc:0.693206	train-auc:0.696234
# [464]	validation-auc:0.693201	train-auc:0.696252
# [465]	validation-auc:0.69321	train-auc:0.696258
# [466]	validation-auc:0.693228	train-auc:0.696271
# [467]	validation-auc:0.693221	train-auc:0.696279
# [468]	validation-auc:0.693222	train-auc:0.696279
# [469]	validation-auc:0.693235	train-auc:0.696297
# [470]	validation-auc:0.693273	train-auc:0.696328
# [471]	validation-auc:0.693276	train-auc:0.696339
# [472]	validation-auc:0.693273	train-auc:0.696352
# [473]	validation-auc:0.693284	train-auc:0.69636
# [474]	validation-auc:0.693288	train-auc:0.69637
# [475]	validation-auc:0.69326	train-auc:0.696394
# [476]	validation-auc:0.693303	train-auc:0.696415
# [477]	validation-auc:0.693269	train-auc:0.696433
# [478]	validation-auc:0.693286	train-auc:0.696437
# [479]	validation-auc:0.693261	train-auc:0.696451
# [480]	validation-auc:0.693277	train-auc:0.696456
# [481]	validation-auc:0.693274	train-auc:0.69646
# [482]	validation-auc:0.693295	train-auc:0.696463
# [483]	validation-auc:0.693308	train-auc:0.696474
# [484]	validation-auc:0.693314	train-auc:0.696502
# [485]	validation-auc:0.693313	train-auc:0.696526
# [486]	validation-auc:0.693318	train-auc:0.696552
# [487]	validation-auc:0.693307	train-auc:0.696559
# [488]	validation-auc:0.693306	train-auc:0.696567
# [489]	validation-auc:0.693306	train-auc:0.696577
# [490]	validation-auc:0.693296	train-auc:0.696593
# [491]	validation-auc:0.693332	train-auc:0.696626
# [492]	validation-auc:0.69333	train-auc:0.696632
# [493]	validation-auc:0.693342	train-auc:0.696634
# [494]	validation-auc:0.693346	train-auc:0.696641
# [495]	validation-auc:0.693337	train-auc:0.696673
# [496]	validation-auc:0.693342	train-auc:0.696686
# [497]	validation-auc:0.693342	train-auc:0.696686
# [498]	validation-auc:0.693336	train-auc:0.696702
# [499]	validation-auc:0.693355	train-auc:0.696716
# [500]	validation-auc:0.693389	train-auc:0.696743
# [501]	validation-auc:0.693421	train-auc:0.696759
# [502]	validation-auc:0.693422	train-auc:0.696776
# [503]	validation-auc:0.693422	train-auc:0.696777
# [504]	validation-auc:0.693422	train-auc:0.696777
# [505]	validation-auc:0.693422	train-auc:0.696777
# [506]	validation-auc:0.693422	train-auc:0.696777
# [507]	validation-auc:0.693442	train-auc:0.696793
# [508]	validation-auc:0.693455	train-auc:0.696796
# [509]	validation-auc:0.69346	train-auc:0.696807
# [510]	validation-auc:0.69346	train-auc:0.696807
# [511]	validation-auc:0.693463	train-auc:0.69682
# [512]	validation-auc:0.693463	train-auc:0.696821
# [513]	validation-auc:0.693456	train-auc:0.696837
# [514]	validation-auc:0.693451	train-auc:0.696843
# [515]	validation-auc:0.693449	train-auc:0.696845
# [516]	validation-auc:0.693487	train-auc:0.696872
# [517]	validation-auc:0.693488	train-auc:0.696879
# [518]	validation-auc:0.693468	train-auc:0.696898
# [519]	validation-auc:0.693472	train-auc:0.696907
# [520]	validation-auc:0.693502	train-auc:0.69695
# [521]	validation-auc:0.693486	train-auc:0.696963
# [522]	validation-auc:0.693519	train-auc:0.697011
# [523]	validation-auc:0.693503	train-auc:0.697027
# [524]	validation-auc:0.693505	train-auc:0.697031
# [525]	validation-auc:0.693502	train-auc:0.69704
# [526]	validation-auc:0.693497	train-auc:0.697048
# [527]	validation-auc:0.693495	train-auc:0.697056
# [528]	validation-auc:0.693483	train-auc:0.697067
# [529]	validation-auc:0.693486	train-auc:0.697075
# [530]	validation-auc:0.693501	train-auc:0.697109
# [531]	validation-auc:0.693531	train-auc:0.697134
# [532]	validation-auc:0.69352	train-auc:0.697141
# [533]	validation-auc:0.693543	train-auc:0.697174
# [534]	validation-auc:0.693548	train-auc:0.697199
# [535]	validation-auc:0.693552	train-auc:0.697225
# [536]	validation-auc:0.693524	train-auc:0.697242
# [537]	validation-auc:0.693524	train-auc:0.69726
# [538]	validation-auc:0.693551	train-auc:0.697283
# [539]	validation-auc:0.693572	train-auc:0.697301
# [540]	validation-auc:0.693576	train-auc:0.697305
# [541]	validation-auc:0.693577	train-auc:0.697306
# [542]	validation-auc:0.693593	train-auc:0.697327
# [543]	validation-auc:0.693592	train-auc:0.697356
# [544]	validation-auc:0.69362	train-auc:0.697374
# [545]	validation-auc:0.69362	train-auc:0.697375
# [546]	validation-auc:0.693634	train-auc:0.697401
# [547]	validation-auc:0.693636	train-auc:0.697402
# [548]	validation-auc:0.693682	train-auc:0.697444
# [549]	validation-auc:0.693665	train-auc:0.697452
# [550]	validation-auc:0.693667	train-auc:0.697462
# [551]	validation-auc:0.693663	train-auc:0.697468
# [552]	validation-auc:0.693677	train-auc:0.697474
# [553]	validation-auc:0.69369	train-auc:0.697482
# [554]	validation-auc:0.693698	train-auc:0.697493
# [555]	validation-auc:0.69369	train-auc:0.697533
# [556]	validation-auc:0.693703	train-auc:0.697553
# [557]	validation-auc:0.693694	train-auc:0.697582
# [558]	validation-auc:0.693724	train-auc:0.697603
# [559]	validation-auc:0.693724	train-auc:0.697608
# [560]	validation-auc:0.693717	train-auc:0.697613
# [561]	validation-auc:0.693687	train-auc:0.697637
# [562]	validation-auc:0.693695	train-auc:0.697653
# [563]	validation-auc:0.693682	train-auc:0.697671
# [564]	validation-auc:0.693671	train-auc:0.697683
# [565]	validation-auc:0.693673	train-auc:0.697693
# [566]	validation-auc:0.693676	train-auc:0.697714
# [567]	validation-auc:0.693681	train-auc:0.697723
# [568]	validation-auc:0.693704	train-auc:0.69776
# [569]	validation-auc:0.693696	train-auc:0.697799
# [570]	validation-auc:0.693711	train-auc:0.697818
# [571]	validation-auc:0.69373	train-auc:0.697839
# [572]	validation-auc:0.693727	train-auc:0.697874
# [573]	validation-auc:0.693697	train-auc:0.697884
# [574]	validation-auc:0.693706	train-auc:0.697903
# [575]	validation-auc:0.693707	train-auc:0.697915
# [576]	validation-auc:0.693729	train-auc:0.697933
# [577]	validation-auc:0.693738	train-auc:0.697937
# [578]	validation-auc:0.69373	train-auc:0.697963
# [579]	validation-auc:0.693721	train-auc:0.697976
# [580]	validation-auc:0.693717	train-auc:0.697991
# [581]	validation-auc:0.693737	train-auc:0.698003
# [582]	validation-auc:0.693739	train-auc:0.698027
# [583]	validation-auc:0.693737	train-auc:0.698031
# [584]	validation-auc:0.693737	train-auc:0.698032
# [585]	validation-auc:0.69373	train-auc:0.698038
# [586]	validation-auc:0.69373	train-auc:0.698044
# [587]	validation-auc:0.693725	train-auc:0.698051
# [588]	validation-auc:0.69371	train-auc:0.698059
# [589]	validation-auc:0.69371	train-auc:0.698059
# [590]	validation-auc:0.693708	train-auc:0.698062
# [591]	validation-auc:0.69371	train-auc:0.698081
# [592]	validation-auc:0.693711	train-auc:0.698083
# [593]	validation-auc:0.693715	train-auc:0.698101
# [594]	validation-auc:0.693733	train-auc:0.698121
# [595]	validation-auc:0.693738	train-auc:0.698127
# [596]	validation-auc:0.693737	train-auc:0.69813
# [597]	validation-auc:0.693724	train-auc:0.698143
# [598]	validation-auc:0.693727	train-auc:0.698147
# [599]	validation-auc:0.693709	train-auc:0.698166
# [600]	validation-auc:0.693704	train-auc:0.698177
# [601]	validation-auc:0.693689	train-auc:0.698187
# [602]	validation-auc:0.693689	train-auc:0.698188
# [603]	validation-auc:0.693689	train-auc:0.698188
# [604]	validation-auc:0.693694	train-auc:0.6982
# [605]	validation-auc:0.693708	train-auc:0.698222
# [606]	validation-auc:0.693696	train-auc:0.698234
# [607]	validation-auc:0.69368	train-auc:0.698252
# [608]	validation-auc:0.693671	train-auc:0.698275
# [609]	validation-auc:0.693669	train-auc:0.698283
# [610]	validation-auc:0.693679	train-auc:0.698294
# [611]	validation-auc:0.693701	train-auc:0.698322
# [612]	validation-auc:0.693698	train-auc:0.698337
# [613]	validation-auc:0.693704	train-auc:0.698359
# [614]	validation-auc:0.69371	train-auc:0.698372
# [615]	validation-auc:0.693704	train-auc:0.698389
# [616]	validation-auc:0.693702	train-auc:0.698398
# [617]	validation-auc:0.693702	train-auc:0.698399
# [618]	validation-auc:0.693701	train-auc:0.698402
# [619]	validation-auc:0.693696	train-auc:0.698421
# [620]	validation-auc:0.693701	train-auc:0.698434
# [621]	validation-auc:0.693697	train-auc:0.69844
# [622]	validation-auc:0.693719	train-auc:0.698453
# [623]	validation-auc:0.693717	train-auc:0.698453
# [624]	validation-auc:0.69373	train-auc:0.698457
# [625]	validation-auc:0.693755	train-auc:0.698484
# [626]	validation-auc:0.693748	train-auc:0.698489
# [627]	validation-auc:0.693747	train-auc:0.698496
# [628]	validation-auc:0.693769	train-auc:0.698538
# [629]	validation-auc:0.693752	train-auc:0.698547
# [630]	validation-auc:0.693738	train-auc:0.698578
# [631]	validation-auc:0.693756	train-auc:0.698585
# [632]	validation-auc:0.693758	train-auc:0.698591
# [633]	validation-auc:0.693771	train-auc:0.698612
# [634]	validation-auc:0.693751	train-auc:0.698644
# [635]	validation-auc:0.693742	train-auc:0.698654
# [636]	validation-auc:0.693741	train-auc:0.698657
# [637]	validation-auc:0.693749	train-auc:0.698655
# [638]	validation-auc:0.693782	train-auc:0.698695
# [639]	validation-auc:0.693825	train-auc:0.698712
# [640]	validation-auc:0.693838	train-auc:0.698732
# [641]	validation-auc:0.693835	train-auc:0.698733
# [642]	validation-auc:0.69381	train-auc:0.69875
# [643]	validation-auc:0.693803	train-auc:0.698758
# [644]	validation-auc:0.693833	train-auc:0.698772
# [645]	validation-auc:0.693834	train-auc:0.698773
# [646]	validation-auc:0.693834	train-auc:0.698773
# [647]	validation-auc:0.693829	train-auc:0.69878
# [648]	validation-auc:0.693828	train-auc:0.698786
# [649]	validation-auc:0.693828	train-auc:0.698786
# [650]	validation-auc:0.693828	train-auc:0.698786
# [651]	validation-auc:0.693829	train-auc:0.698787
# [652]	validation-auc:0.693841	train-auc:0.698795
# [653]	validation-auc:0.693851	train-auc:0.698814
# [654]	validation-auc:0.693851	train-auc:0.698823
# [655]	validation-auc:0.693852	train-auc:0.698824
# [656]	validation-auc:0.693852	train-auc:0.698824
# [657]	validation-auc:0.693853	train-auc:0.698839
# [658]	validation-auc:0.693846	train-auc:0.69886
# [659]	validation-auc:0.693838	train-auc:0.698865
# [660]	validation-auc:0.693874	train-auc:0.698883
# [661]	validation-auc:0.693876	train-auc:0.698892
# [662]	validation-auc:0.693904	train-auc:0.698916
# [663]	validation-auc:0.693911	train-auc:0.698941
# [664]	validation-auc:0.693903	train-auc:0.698947
# [665]	validation-auc:0.693903	train-auc:0.698964
# [666]	validation-auc:0.693902	train-auc:0.698969
# [667]	validation-auc:0.693909	train-auc:0.698966
# [668]	validation-auc:0.693907	train-auc:0.698978
# [669]	validation-auc:0.693905	train-auc:0.698994
# [670]	validation-auc:0.693916	train-auc:0.699008
# [671]	validation-auc:0.693923	train-auc:0.699012
# [672]	validation-auc:0.693923	train-auc:0.699012
# [673]	validation-auc:0.693927	train-auc:0.699021
# [674]	validation-auc:0.693925	train-auc:0.699033
# [675]	validation-auc:0.693904	train-auc:0.699039
# [676]	validation-auc:0.693901	train-auc:0.699037
# [677]	validation-auc:0.69391	train-auc:0.699043
# [678]	validation-auc:0.69391	train-auc:0.699043
# [679]	validation-auc:0.693913	train-auc:0.699059
# [680]	validation-auc:0.693941	train-auc:0.699083
# [681]	validation-auc:0.693946	train-auc:0.699093
# [682]	validation-auc:0.693974	train-auc:0.69912
# [683]	validation-auc:0.693974	train-auc:0.699118
# [684]	validation-auc:0.693958	train-auc:0.699123
# [685]	validation-auc:0.693961	train-auc:0.699123
# [686]	validation-auc:0.693973	train-auc:0.699127
# [687]	validation-auc:0.693973	train-auc:0.699126
# [688]	validation-auc:0.693973	train-auc:0.699134
# [689]	validation-auc:0.693977	train-auc:0.699141
# [690]	validation-auc:0.693977	train-auc:0.699148
# [691]	validation-auc:0.693976	train-auc:0.699146
# [692]	validation-auc:0.693985	train-auc:0.699149
# [693]	validation-auc:0.693977	train-auc:0.699159
# [694]	validation-auc:0.69396	train-auc:0.699169
# [695]	validation-auc:0.693955	train-auc:0.699171
# [696]	validation-auc:0.693955	train-auc:0.699171
# [697]	validation-auc:0.693956	train-auc:0.699172
# [698]	validation-auc:0.693954	train-auc:0.699177
# [699]	validation-auc:0.693949	train-auc:0.699181
# [700]	validation-auc:0.693949	train-auc:0.699181
# [701]	validation-auc:0.693934	train-auc:0.699201
# [702]	validation-auc:0.693923	train-auc:0.699212
# [703]	validation-auc:0.69391	train-auc:0.699224
# [704]	validation-auc:0.693905	train-auc:0.699237
# [705]	validation-auc:0.693893	train-auc:0.699257
# [706]	validation-auc:0.693879	train-auc:0.699265
# [707]	validation-auc:0.693871	train-auc:0.699273
# [708]	validation-auc:0.693861	train-auc:0.699276
# [709]	validation-auc:0.693879	train-auc:0.699283
# [710]	validation-auc:0.693886	train-auc:0.699289
# [711]	validation-auc:0.693885	train-auc:0.699293
# [712]	validation-auc:0.693905	train-auc:0.699312
# [713]	validation-auc:0.693915	train-auc:0.699347
# [714]	validation-auc:0.693921	train-auc:0.699348
# [715]	validation-auc:0.693918	train-auc:0.699364
# [716]	validation-auc:0.693916	train-auc:0.699372
# [717]	validation-auc:0.693927	train-auc:0.699377
# [718]	validation-auc:0.693935	train-auc:0.699385
# [719]	validation-auc:0.693933	train-auc:0.699386
# [720]	validation-auc:0.693928	train-auc:0.699398
# [721]	validation-auc:0.693918	train-auc:0.699423
# [722]	validation-auc:0.693929	train-auc:0.699436
# [723]	validation-auc:0.693928	train-auc:0.699454
# [724]	validation-auc:0.693912	train-auc:0.699475
# [725]	validation-auc:0.693902	train-auc:0.699483
# [726]	validation-auc:0.693892	train-auc:0.699493
# [727]	validation-auc:0.693898	train-auc:0.699496
# [728]	validation-auc:0.693914	train-auc:0.699509
# [729]	validation-auc:0.69392	train-auc:0.699517
# [730]	validation-auc:0.693914	train-auc:0.699518
# [731]	validation-auc:0.693914	train-auc:0.699519
# [732]	validation-auc:0.693929	train-auc:0.699524
# [733]	validation-auc:0.693944	train-auc:0.699547
# [734]	validation-auc:0.693942	train-auc:0.699551
# [735]	validation-auc:0.693943	train-auc:0.699554
# [736]	validation-auc:0.69395	train-auc:0.699572
# [737]	validation-auc:0.693942	train-auc:0.699579
# [738]	validation-auc:0.693955	train-auc:0.699583
# [739]	validation-auc:0.693937	train-auc:0.699591
# [740]	validation-auc:0.693935	train-auc:0.699617
# [741]	validation-auc:0.693965	train-auc:0.699653
# [742]	validation-auc:0.693965	train-auc:0.699661
# [743]	validation-auc:0.693971	train-auc:0.699663
# [744]	validation-auc:0.693971	train-auc:0.699664
# [745]	validation-auc:0.693966	train-auc:0.699665
# [746]	validation-auc:0.693966	train-auc:0.699665
# [747]	validation-auc:0.693957	train-auc:0.699679
# [748]	validation-auc:0.693953	train-auc:0.699687
# [749]	validation-auc:0.69393	train-auc:0.699696
# [750]	validation-auc:0.693922	train-auc:0.69971
# [751]	validation-auc:0.693926	train-auc:0.699721
# [752]	validation-auc:0.693912	train-auc:0.699729
# [753]	validation-auc:0.693904	train-auc:0.699734
# [754]	validation-auc:0.693932	train-auc:0.699759
# [755]	validation-auc:0.69394	train-auc:0.699778
# [756]	validation-auc:0.693933	train-auc:0.69979
# [757]	validation-auc:0.693922	train-auc:0.6998
# [758]	validation-auc:0.693919	train-auc:0.699813
# [759]	validation-auc:0.693917	train-auc:0.699817
# [760]	validation-auc:0.693923	train-auc:0.699824
# [761]	validation-auc:0.693913	train-auc:0.699832
# [762]	validation-auc:0.693913	train-auc:0.699832
# [763]	validation-auc:0.693906	train-auc:0.699838
# [764]	validation-auc:0.693906	train-auc:0.699839
# [765]	validation-auc:0.693906	train-auc:0.699839
# [766]	validation-auc:0.693906	train-auc:0.699839
# [767]	validation-auc:0.693903	train-auc:0.699845
# [768]	validation-auc:0.693914	train-auc:0.69987
# [769]	validation-auc:0.693917	train-auc:0.699871
# [770]	validation-auc:0.693903	train-auc:0.699875
# [771]	validation-auc:0.693909	train-auc:0.699878
# [772]	validation-auc:0.693901	train-auc:0.699885
# [773]	validation-auc:0.693901	train-auc:0.699885
# [774]	validation-auc:0.693894	train-auc:0.699892
# [775]	validation-auc:0.693887	train-auc:0.699889
# [776]	validation-auc:0.693881	train-auc:0.699895
# [777]	validation-auc:0.693881	train-auc:0.699895
# [778]	validation-auc:0.693878	train-auc:0.699897
# [779]	validation-auc:0.693891	train-auc:0.699915
# [780]	validation-auc:0.693891	train-auc:0.699915
# [781]	validation-auc:0.693892	train-auc:0.699919
# [782]	validation-auc:0.693897	train-auc:0.699918
# [783]	validation-auc:0.693911	train-auc:0.699921
# [784]	validation-auc:0.693908	train-auc:0.699928
# [785]	validation-auc:0.693909	train-auc:0.699946
# [786]	validation-auc:0.693883	train-auc:0.699957
# [787]	validation-auc:0.693885	train-auc:0.699957
# [788]	validation-auc:0.693893	train-auc:0.699963
# [789]	validation-auc:0.693889	train-auc:0.699969
# [790]	validation-auc:0.693883	train-auc:0.699981
# [791]	validation-auc:0.693891	train-auc:0.700001
# [792]	validation-auc:0.693898	train-auc:0.700009
# [793]	validation-auc:0.693896	train-auc:0.700023
# [794]	validation-auc:0.69389	train-auc:0.700033
# [795]	validation-auc:0.693883	train-auc:0.700037
# [796]	validation-auc:0.693879	train-auc:0.700039
# [797]	validation-auc:0.693883	train-auc:0.700051
# [798]	validation-auc:0.693878	train-auc:0.700078
# [799]	validation-auc:0.693878	train-auc:0.700086
# [800]	validation-auc:0.693876	train-auc:0.700092
# [801]	validation-auc:0.693876	train-auc:0.700092
# [802]	validation-auc:0.693887	train-auc:0.700097
# [803]	validation-auc:0.693888	train-auc:0.700097
# [804]	validation-auc:0.693888	train-auc:0.700098
# [805]	validation-auc:0.693896	train-auc:0.700116
# [806]	validation-auc:0.693897	train-auc:0.700119
# [807]	validation-auc:0.693898	train-auc:0.70012
# [808]	validation-auc:0.693898	train-auc:0.70012
# [809]	validation-auc:0.693906	train-auc:0.700129
# [810]	validation-auc:0.693914	train-auc:0.700147
# [811]	validation-auc:0.693898	train-auc:0.700156
# [812]	validation-auc:0.693898	train-auc:0.700156
# [813]	validation-auc:0.693892	train-auc:0.70016
# [814]	validation-auc:0.693892	train-auc:0.700161
# [815]	validation-auc:0.693892	train-auc:0.700161
# [816]	validation-auc:0.693893	train-auc:0.700169
# [817]	validation-auc:0.693884	train-auc:0.700196
# [818]	validation-auc:0.693876	train-auc:0.700204
# [819]	validation-auc:0.69388	train-auc:0.700229
# [820]	validation-auc:0.69389	train-auc:0.700243
# [821]	validation-auc:0.693891	train-auc:0.70025
# [822]	validation-auc:0.693888	train-auc:0.700278
# [823]	validation-auc:0.693887	train-auc:0.70029
# [824]	validation-auc:0.69388	train-auc:0.700301
# [825]	validation-auc:0.693875	train-auc:0.700308
# [826]	validation-auc:0.693874	train-auc:0.70031
# [827]	validation-auc:0.693868	train-auc:0.700317
# [828]	validation-auc:0.693864	train-auc:0.700323
# [829]	validation-auc:0.693861	train-auc:0.700328
# [830]	validation-auc:0.693846	train-auc:0.700335
# [831]	validation-auc:0.693852	train-auc:0.700347
# [832]	validation-auc:0.693851	train-auc:0.700371
# [833]	validation-auc:0.69386	train-auc:0.700386
# [834]	validation-auc:0.693868	train-auc:0.700391
# [835]	validation-auc:0.693866	train-auc:0.700403
# [836]	validation-auc:0.693859	train-auc:0.700408
# [837]	validation-auc:0.693861	train-auc:0.700421
# [838]	validation-auc:0.693877	train-auc:0.700453
# [839]	validation-auc:0.693892	train-auc:0.700463
# [840]	validation-auc:0.69389	train-auc:0.700463
# [841]	validation-auc:0.693891	train-auc:0.700467
# [842]	validation-auc:0.693891	train-auc:0.700467
# [843]	validation-auc:0.693878	train-auc:0.700485
# [844]	validation-auc:0.693883	train-auc:0.700501
# [845]	validation-auc:0.693883	train-auc:0.700501
# [846]	validation-auc:0.693874	train-auc:0.700506
# [847]	validation-auc:0.693886	train-auc:0.70051
# [848]	validation-auc:0.693876	train-auc:0.70052
# [849]	validation-auc:0.693894	train-auc:0.700537
# [850]	validation-auc:0.693893	train-auc:0.700542
# [851]	validation-auc:0.693892	train-auc:0.700555
# [852]	validation-auc:0.693881	train-auc:0.700563
# [853]	validation-auc:0.693889	train-auc:0.700579
# [854]	validation-auc:0.693891	train-auc:0.700582
# [855]	validation-auc:0.693882	train-auc:0.700594
# [856]	validation-auc:0.693886	train-auc:0.700591
# [857]	validation-auc:0.693887	train-auc:0.700603
# [858]	validation-auc:0.693876	train-auc:0.700612
# [859]	validation-auc:0.693851	train-auc:0.700618
# [860]	validation-auc:0.693852	train-auc:0.700629
# [861]	validation-auc:0.693848	train-auc:0.700637
# [862]	validation-auc:0.69385	train-auc:0.70064
# [863]	validation-auc:0.693851	train-auc:0.700644
# [864]	validation-auc:0.693847	train-auc:0.70066
# [865]	validation-auc:0.693843	train-auc:0.700663
# [866]	validation-auc:0.693851	train-auc:0.700671
# [867]	validation-auc:0.693853	train-auc:0.700681
# [868]	validation-auc:0.693888	train-auc:0.700712
# [869]	validation-auc:0.693882	train-auc:0.700719
# [870]	validation-auc:0.693879	train-auc:0.700728
# [871]	validation-auc:0.693881	train-auc:0.700735
# [872]	validation-auc:0.693894	train-auc:0.700762
# [873]	validation-auc:0.693899	train-auc:0.700765
# [874]	validation-auc:0.693886	train-auc:0.700776
# [875]	validation-auc:0.693879	train-auc:0.700783
# [876]	validation-auc:0.693881	train-auc:0.700786
# [877]	validation-auc:0.693884	train-auc:0.700789
# [878]	validation-auc:0.693879	train-auc:0.700795
# [879]	validation-auc:0.69387	train-auc:0.700806
# [880]	validation-auc:0.693889	train-auc:0.700823
# [881]	validation-auc:0.693872	train-auc:0.700845
# [882]	validation-auc:0.693863	train-auc:0.700851
# [883]	validation-auc:0.693851	train-auc:0.700861
# [884]	validation-auc:0.693861	train-auc:0.70088
# [885]	validation-auc:0.693862	train-auc:0.700884
# [886]	validation-auc:0.693848	train-auc:0.700894
# [887]	validation-auc:0.693854	train-auc:0.700912
# [888]	validation-auc:0.693849	train-auc:0.700913
# [889]	validation-auc:0.693844	train-auc:0.700928
# [890]	validation-auc:0.693855	train-auc:0.700939
# [891]	validation-auc:0.693858	train-auc:0.700958
# [892]	validation-auc:0.693857	train-auc:0.700979
# [893]	validation-auc:0.693873	train-auc:0.700978
# [894]	validation-auc:0.693873	train-auc:0.700978
# [895]	validation-auc:0.693868	train-auc:0.701
# [896]	validation-auc:0.693881	train-auc:0.700998
# [897]	validation-auc:0.693869	train-auc:0.70102
# [898]	validation-auc:0.693882	train-auc:0.701037
# [899]	validation-auc:0.693886	train-auc:0.701052
# [900]	validation-auc:0.693881	train-auc:0.701059
# [901]	validation-auc:0.693879	train-auc:0.701071
# [902]	validation-auc:0.693868	train-auc:0.701091
# [903]	validation-auc:0.693886	train-auc:0.701103
# [904]	validation-auc:0.693889	train-auc:0.701111
# [905]	validation-auc:0.693888	train-auc:0.701114
# [906]	validation-auc:0.693881	train-auc:0.701124
# [907]	validation-auc:0.693871	train-auc:0.701144
# [908]	validation-auc:0.693878	train-auc:0.701152
# [909]	validation-auc:0.693879	train-auc:0.701153
# [910]	validation-auc:0.693879	train-auc:0.701153
# [911]	validation-auc:0.693885	train-auc:0.701169
# [912]	validation-auc:0.693869	train-auc:0.701183
# [913]	validation-auc:0.693846	train-auc:0.701204
# [914]	validation-auc:0.69384	train-auc:0.70123
# [915]	validation-auc:0.693841	train-auc:0.701232
# [916]	validation-auc:0.693845	train-auc:0.701239
# [917]	validation-auc:0.693845	train-auc:0.701239
# [918]	validation-auc:0.693845	train-auc:0.701239
# [919]	validation-auc:0.693845	train-auc:0.701239
# [920]	validation-auc:0.693856	train-auc:0.701267
# [921]	validation-auc:0.693847	train-auc:0.701284
# [922]	validation-auc:0.693826	train-auc:0.701301
# [923]	validation-auc:0.693823	train-auc:0.70132
# [924]	validation-auc:0.693829	train-auc:0.701342
# [925]	validation-auc:0.693817	train-auc:0.701352
# [926]	validation-auc:0.693825	train-auc:0.701357
# [927]	validation-auc:0.693833	train-auc:0.701364
# [928]	validation-auc:0.693841	train-auc:0.701372
# [929]	validation-auc:0.693844	train-auc:0.701378
# [930]	validation-auc:0.693867	train-auc:0.701406
# [931]	validation-auc:0.693856	train-auc:0.701416
# [932]	validation-auc:0.69385	train-auc:0.70142
# [933]	validation-auc:0.693851	train-auc:0.701429
# [934]	validation-auc:0.693844	train-auc:0.701433
# [935]	validation-auc:0.693839	train-auc:0.701441
# [936]	validation-auc:0.693829	train-auc:0.701445
# [937]	validation-auc:0.693823	train-auc:0.701447
# [938]	validation-auc:0.693818	train-auc:0.701458
# [939]	validation-auc:0.693815	train-auc:0.701479
# [940]	validation-auc:0.693806	train-auc:0.701496
# [941]	validation-auc:0.693795	train-auc:0.701504
# [942]	validation-auc:0.693794	train-auc:0.70151
# [943]	validation-auc:0.693809	train-auc:0.701522
# [944]	validation-auc:0.693819	train-auc:0.70153
# [945]	validation-auc:0.693811	train-auc:0.701548
# [946]	validation-auc:0.693811	train-auc:0.70157
# [947]	validation-auc:0.693832	train-auc:0.701577
# [948]	validation-auc:0.693842	train-auc:0.701589
# [949]	validation-auc:0.693842	train-auc:0.701609
# [950]	validation-auc:0.693843	train-auc:0.701613
# [951]	validation-auc:0.693837	train-auc:0.701621
# [952]	validation-auc:0.693814	train-auc:0.701627
# [953]	validation-auc:0.693803	train-auc:0.70164
# [954]	validation-auc:0.693801	train-auc:0.701647
# [955]	validation-auc:0.693802	train-auc:0.70166
# [956]	validation-auc:0.693794	train-auc:0.701669
# [957]	validation-auc:0.693812	train-auc:0.701674
# [958]	validation-auc:0.693824	train-auc:0.701687
# [959]	validation-auc:0.693824	train-auc:0.701691
# [960]	validation-auc:0.693806	train-auc:0.7017
# [961]	validation-auc:0.693811	train-auc:0.701706
# [962]	validation-auc:0.69384	train-auc:0.701722
# [963]	validation-auc:0.693842	train-auc:0.701728
# [964]	validation-auc:0.693836	train-auc:0.701734
# [965]	validation-auc:0.693811	train-auc:0.701743
# [966]	validation-auc:0.693797	train-auc:0.701753
# [967]	validation-auc:0.693794	train-auc:0.701775
# [968]	validation-auc:0.693784	train-auc:0.701778
# [969]	validation-auc:0.693787	train-auc:0.701783
# [970]	validation-auc:0.693788	train-auc:0.7018
# [971]	validation-auc:0.693788	train-auc:0.701803
# [972]	validation-auc:0.693783	train-auc:0.701812
# [973]	validation-auc:0.693786	train-auc:0.701815
# [974]	validation-auc:0.693779	train-auc:0.701823
# [975]	validation-auc:0.693778	train-auc:0.70183
# [976]	validation-auc:0.69377	train-auc:0.701832
# [977]	validation-auc:0.693767	train-auc:0.701834
# [978]	validation-auc:0.693772	train-auc:0.701835
# [979]	validation-auc:0.693772	train-auc:0.701835
# [980]	validation-auc:0.693787	train-auc:0.701859
# [981]	validation-auc:0.693798	train-auc:0.70187
# [982]	validation-auc:0.693807	train-auc:0.701875
# [983]	validation-auc:0.69381	train-auc:0.701885
# [984]	validation-auc:0.693796	train-auc:0.701896
# [985]	validation-auc:0.6938	train-auc:0.701923
# ...
# [9680]	validation-auc:0.686611	train-auc:0.728744
# [9681]	validation-auc:0.686611	train-auc:0.728744
# [9682]	validation-auc:0.686608	train-auc:0.728748
# [9683]	validation-auc:0.686609	train-auc:0.728747
# [9684]	validation-auc:0.68661	train-auc:0.72875
# [9685]	validation-auc:0.68661	train-auc:0.72875
# [9686]	validation-auc:0.686608	train-auc:0.728751
# [9687]	validation-auc:0.686607	train-auc:0.728752
# [9688]	validation-auc:0.686609	train-auc:0.728754
# [9689]	validation-auc:0.686604	train-auc:0.728755
# [9690]	validation-auc:0.686601	train-auc:0.728758
# [9691]	validation-auc:0.6866	train-auc:0.728758
# [9692]	validation-auc:0.686597	train-auc:0.728763
# [9693]	validation-auc:0.686598	train-auc:0.728762
# [9694]	validation-auc:0.686598	train-auc:0.728762
# [9695]	validation-auc:0.686597	train-auc:0.728762
# [9696]	validation-auc:0.686598	train-auc:0.728762
# [9697]	validation-auc:0.686596	train-auc:0.728764
# [9698]	validation-auc:0.686597	train-auc:0.728765
# [9699]	validation-auc:0.686598	train-auc:0.728765
# [9700]	validation-auc:0.686598	train-auc:0.728765
# [9701]	validation-auc:0.686598	train-auc:0.728765
# [9702]	validation-auc:0.6866	train-auc:0.728766
# [9703]	validation-auc:0.6866	train-auc:0.728768
# [9704]	validation-auc:0.6866	train-auc:0.728768
# [9705]	validation-auc:0.6866	train-auc:0.728766
# [9706]	validation-auc:0.686601	train-auc:0.728767
# [9707]	validation-auc:0.686605	train-auc:0.728769
# [9708]	validation-auc:0.686602	train-auc:0.728769
# [9709]	validation-auc:0.686603	train-auc:0.72877
# [9710]	validation-auc:0.686601	train-auc:0.728772
# [9711]	validation-auc:0.686601	train-auc:0.728773
# [9712]	validation-auc:0.686603	train-auc:0.728774
# [9713]	validation-auc:0.686604	train-auc:0.728774
# [9714]	validation-auc:0.686601	train-auc:0.728778
# [9715]	validation-auc:0.686596	train-auc:0.72878
# [9716]	validation-auc:0.686595	train-auc:0.72878
# [9717]	validation-auc:0.686598	train-auc:0.728782
# [9718]	validation-auc:0.686603	train-auc:0.728785
# [9719]	validation-auc:0.686603	train-auc:0.728785
# [9720]	validation-auc:0.686603	train-auc:0.728787
# [9721]	validation-auc:0.686601	train-auc:0.728788
# [9722]	validation-auc:0.686599	train-auc:0.728788
# [9723]	validation-auc:0.686599	train-auc:0.728788
# [9724]	validation-auc:0.686599	train-auc:0.728789
# [9725]	validation-auc:0.686594	train-auc:0.728791
# [9726]	validation-auc:0.686596	train-auc:0.728791
# [9727]	validation-auc:0.686601	train-auc:0.728795
# [9728]	validation-auc:0.686602	train-auc:0.728794
# [9729]	validation-auc:0.6866	train-auc:0.728792
# [9730]	validation-auc:0.686601	train-auc:0.728792
# [9731]	validation-auc:0.6866	train-auc:0.728792
# [9732]	validation-auc:0.686589	train-auc:0.728794
# [9733]	validation-auc:0.686589	train-auc:0.728794
# [9734]	validation-auc:0.686589	train-auc:0.728794
# [9735]	validation-auc:0.686589	train-auc:0.728796
# [9736]	validation-auc:0.686589	train-auc:0.728797
# [9737]	validation-auc:0.686587	train-auc:0.728798
# [9738]	validation-auc:0.686582	train-auc:0.728799
# [9739]	validation-auc:0.686578	train-auc:0.728803
# [9740]	validation-auc:0.686578	train-auc:0.728803
# [9741]	validation-auc:0.686578	train-auc:0.728803
# [9742]	validation-auc:0.686578	train-auc:0.728805
# [9743]	validation-auc:0.686578	train-auc:0.728805
# [9744]	validation-auc:0.686578	train-auc:0.728805
# [9745]	validation-auc:0.686578	train-auc:0.728805
# [9746]	validation-auc:0.686578	train-auc:0.728807
# [9747]	validation-auc:0.686576	train-auc:0.728808
# [9748]	validation-auc:0.686574	train-auc:0.728811
# [9749]	validation-auc:0.68657	train-auc:0.728812
# [9750]	validation-auc:0.686571	train-auc:0.728812
# [9751]	validation-auc:0.686566	train-auc:0.728814
# [9752]	validation-auc:0.686563	train-auc:0.728817
# [9753]	validation-auc:0.686565	train-auc:0.72882
# [9754]	validation-auc:0.686566	train-auc:0.728821
# [9755]	validation-auc:0.686566	train-auc:0.72882
# [9756]	validation-auc:0.686567	train-auc:0.728822
# [9757]	validation-auc:0.686568	train-auc:0.728822
# [9758]	validation-auc:0.686568	train-auc:0.728822
# [9759]	validation-auc:0.686568	train-auc:0.728822
# [9760]	validation-auc:0.686566	train-auc:0.728822
# [9761]	validation-auc:0.686567	train-auc:0.728822
# [9762]	validation-auc:0.686567	train-auc:0.728821
# [9763]	validation-auc:0.686567	train-auc:0.728821
# [9764]	validation-auc:0.686567	train-auc:0.728821
# [9765]	validation-auc:0.686568	train-auc:0.728824
# [9766]	validation-auc:0.686566	train-auc:0.728827
# [9767]	validation-auc:0.686566	train-auc:0.728827
# [9768]	validation-auc:0.686564	train-auc:0.72883
# [9769]	validation-auc:0.686561	train-auc:0.72883
# [9770]	validation-auc:0.686564	train-auc:0.728829
# [9771]	validation-auc:0.686565	train-auc:0.728831
# [9772]	validation-auc:0.686563	train-auc:0.728833
# [9773]	validation-auc:0.686556	train-auc:0.728837
# [9774]	validation-auc:0.686559	train-auc:0.72884
# [9775]	validation-auc:0.686555	train-auc:0.728843
# [9776]	validation-auc:0.686555	train-auc:0.728843
# [9777]	validation-auc:0.686555	train-auc:0.728843
# [9778]	validation-auc:0.686558	train-auc:0.728843
# [9779]	validation-auc:0.686556	train-auc:0.728844
# [9780]	validation-auc:0.686556	train-auc:0.728844
# [9781]	validation-auc:0.686556	train-auc:0.728844
# [9782]	validation-auc:0.686556	train-auc:0.728844
# [9783]	validation-auc:0.686561	train-auc:0.728846
# [9784]	validation-auc:0.686563	train-auc:0.728846
# [9785]	validation-auc:0.686563	train-auc:0.728846
# [9786]	validation-auc:0.686563	train-auc:0.728846
# [9787]	validation-auc:0.686558	train-auc:0.728846
# [9788]	validation-auc:0.686559	train-auc:0.728849
# [9789]	validation-auc:0.686559	train-auc:0.728855
# [9790]	validation-auc:0.686556	train-auc:0.728857
# [9791]	validation-auc:0.686559	train-auc:0.728858
# [9792]	validation-auc:0.686558	train-auc:0.728858
# [9793]	validation-auc:0.686558	train-auc:0.728858
# [9794]	validation-auc:0.686558	train-auc:0.728858
# [9795]	validation-auc:0.686558	train-auc:0.728858
# [9796]	validation-auc:0.686554	train-auc:0.728864
# [9797]	validation-auc:0.686547	train-auc:0.72887
# [9798]	validation-auc:0.686546	train-auc:0.728874
# [9799]	validation-auc:0.686544	train-auc:0.728878
# [9800]	validation-auc:0.686544	train-auc:0.72888
# [9801]	validation-auc:0.686542	train-auc:0.728881
# [9802]	validation-auc:0.686545	train-auc:0.728883
# [9803]	validation-auc:0.686543	train-auc:0.728884
# [9804]	validation-auc:0.686544	train-auc:0.728884
# [9805]	validation-auc:0.686549	train-auc:0.728887
# [9806]	validation-auc:0.686549	train-auc:0.728889
# [9807]	validation-auc:0.686548	train-auc:0.72889
# [9808]	validation-auc:0.686547	train-auc:0.72889
# [9809]	validation-auc:0.686545	train-auc:0.728891
# [9810]	validation-auc:0.686544	train-auc:0.728891
# [9811]	validation-auc:0.686545	train-auc:0.728893
# [9812]	validation-auc:0.686539	train-auc:0.728898
# [9813]	validation-auc:0.68654	train-auc:0.728901
# [9814]	validation-auc:0.686532	train-auc:0.728906
# [9815]	validation-auc:0.686531	train-auc:0.728908
# [9816]	validation-auc:0.686527	train-auc:0.728911
# [9817]	validation-auc:0.686528	train-auc:0.728914
# [9818]	validation-auc:0.686526	train-auc:0.728916
# [9819]	validation-auc:0.686522	train-auc:0.728918
# [9820]	validation-auc:0.686521	train-auc:0.728917
# [9821]	validation-auc:0.686519	train-auc:0.728919
# [9822]	validation-auc:0.68652	train-auc:0.72892
# [9823]	validation-auc:0.686519	train-auc:0.728925
# [9824]	validation-auc:0.686518	train-auc:0.728925
# [9825]	validation-auc:0.686516	train-auc:0.728929
# [9826]	validation-auc:0.686517	train-auc:0.728933
# [9827]	validation-auc:0.686515	train-auc:0.728935
# [9828]	validation-auc:0.686512	train-auc:0.728937
# [9829]	validation-auc:0.686508	train-auc:0.728938
# [9830]	validation-auc:0.686509	train-auc:0.728943
# [9831]	validation-auc:0.686518	train-auc:0.728947
# [9832]	validation-auc:0.686519	train-auc:0.728947
# [9833]	validation-auc:0.686519	train-auc:0.728947
# [9834]	validation-auc:0.686519	train-auc:0.728947
# [9835]	validation-auc:0.686521	train-auc:0.72895
# [9836]	validation-auc:0.686521	train-auc:0.728952
# [9837]	validation-auc:0.686517	train-auc:0.728954
# [9838]	validation-auc:0.686509	train-auc:0.72896
# [9839]	validation-auc:0.686514	train-auc:0.728962
# [9840]	validation-auc:0.686514	train-auc:0.728971
# [9841]	validation-auc:0.686511	train-auc:0.728973
# [9842]	validation-auc:0.686512	train-auc:0.728974
# [9843]	validation-auc:0.686516	train-auc:0.728976
# [9844]	validation-auc:0.686522	train-auc:0.728974
# [9845]	validation-auc:0.686522	train-auc:0.728974
# [9846]	validation-auc:0.686522	train-auc:0.728975
# [9847]	validation-auc:0.686532	train-auc:0.728979
# [9848]	validation-auc:0.686532	train-auc:0.728979
# [9849]	validation-auc:0.686534	train-auc:0.728979
# [9850]	validation-auc:0.686532	train-auc:0.728984
# [9851]	validation-auc:0.686534	train-auc:0.728991
# [9852]	validation-auc:0.686535	train-auc:0.728994
# [9853]	validation-auc:0.686538	train-auc:0.728998
# [9854]	validation-auc:0.686539	train-auc:0.729002
# [9855]	validation-auc:0.686541	train-auc:0.729
# [9856]	validation-auc:0.686541	train-auc:0.729001
# [9857]	validation-auc:0.686541	train-auc:0.729001
# [9858]	validation-auc:0.686536	train-auc:0.729002
# [9859]	validation-auc:0.686533	train-auc:0.729005
# [9860]	validation-auc:0.686531	train-auc:0.729007
# [9861]	validation-auc:0.686531	train-auc:0.729007
# [9862]	validation-auc:0.686532	train-auc:0.729007
# [9863]	validation-auc:0.686532	train-auc:0.729007
# [9864]	validation-auc:0.686532	train-auc:0.729009
# [9865]	validation-auc:0.686526	train-auc:0.729015
# [9866]	validation-auc:0.686531	train-auc:0.729023
# [9867]	validation-auc:0.686531	train-auc:0.729023
# [9868]	validation-auc:0.68653	train-auc:0.729029
# [9869]	validation-auc:0.686522	train-auc:0.729033
# [9870]	validation-auc:0.68652	train-auc:0.729034
# [9871]	validation-auc:0.686518	train-auc:0.729035
# [9872]	validation-auc:0.686518	train-auc:0.729035
# [9873]	validation-auc:0.686519	train-auc:0.729035
# [9874]	validation-auc:0.68652	train-auc:0.72904
# [9875]	validation-auc:0.686516	train-auc:0.729042
# [9876]	validation-auc:0.686518	train-auc:0.729044
# [9877]	validation-auc:0.686518	train-auc:0.729044
# [9878]	validation-auc:0.686518	train-auc:0.729044
# [9879]	validation-auc:0.686519	train-auc:0.729044
# [9880]	validation-auc:0.686525	train-auc:0.729048
# [9881]	validation-auc:0.686522	train-auc:0.729049
# [9882]	validation-auc:0.686523	train-auc:0.72905
# [9883]	validation-auc:0.686525	train-auc:0.729052
# [9884]	validation-auc:0.686523	train-auc:0.729053
# [9885]	validation-auc:0.686513	train-auc:0.729055
# [9886]	validation-auc:0.686513	train-auc:0.729055
# [9887]	validation-auc:0.686517	train-auc:0.729057
# [9888]	validation-auc:0.686512	train-auc:0.729058
# [9889]	validation-auc:0.686505	train-auc:0.729061
# [9890]	validation-auc:0.686505	train-auc:0.729061
# [9891]	validation-auc:0.686505	train-auc:0.729063
# [9892]	validation-auc:0.686501	train-auc:0.729064
# [9893]	validation-auc:0.6865	train-auc:0.729065
# [9894]	validation-auc:0.686499	train-auc:0.729065
# [9895]	validation-auc:0.686499	train-auc:0.729063
# [9896]	validation-auc:0.686501	train-auc:0.729064
# [9897]	validation-auc:0.686504	train-auc:0.729062
# [9898]	validation-auc:0.686501	train-auc:0.729069
# [9899]	validation-auc:0.686499	train-auc:0.729069
# [9900]	validation-auc:0.686501	train-auc:0.729073
# [9901]	validation-auc:0.686494	train-auc:0.729078
# [9902]	validation-auc:0.686502	train-auc:0.729083
# [9903]	validation-auc:0.686502	train-auc:0.729083
# [9904]	validation-auc:0.686501	train-auc:0.729083
# [9905]	validation-auc:0.686504	train-auc:0.729091
# [9906]	validation-auc:0.686501	train-auc:0.729095
# [9907]	validation-auc:0.6865	train-auc:0.729095
# [9908]	validation-auc:0.686499	train-auc:0.729097
# [9909]	validation-auc:0.6865	train-auc:0.729097
# [9910]	validation-auc:0.686497	train-auc:0.729099
# [9911]	validation-auc:0.686498	train-auc:0.7291
# [9912]	validation-auc:0.686499	train-auc:0.7291
# [9913]	validation-auc:0.686501	train-auc:0.729105
# [9914]	validation-auc:0.686498	train-auc:0.729106
# [9915]	validation-auc:0.686498	train-auc:0.729105
# [9916]	validation-auc:0.686498	train-auc:0.729107
# [9917]	validation-auc:0.686493	train-auc:0.729111
# [9918]	validation-auc:0.686495	train-auc:0.729112
# [9919]	validation-auc:0.686492	train-auc:0.729113
# [9920]	validation-auc:0.686493	train-auc:0.729114
# [9921]	validation-auc:0.686492	train-auc:0.729114
# [9922]	validation-auc:0.686493	train-auc:0.729116
# [9923]	validation-auc:0.686486	train-auc:0.729121
# [9924]	validation-auc:0.686492	train-auc:0.729123
# [9925]	validation-auc:0.686494	train-auc:0.729123
# [9926]	validation-auc:0.686493	train-auc:0.729123
# [9927]	validation-auc:0.686493	train-auc:0.729123
# [9928]	validation-auc:0.686494	train-auc:0.729125
# [9929]	validation-auc:0.686492	train-auc:0.729128
# [9930]	validation-auc:0.686494	train-auc:0.72913
# [9931]	validation-auc:0.686495	train-auc:0.729131
# [9932]	validation-auc:0.686493	train-auc:0.729137
# [9933]	validation-auc:0.686485	train-auc:0.729141
# [9934]	validation-auc:0.686485	train-auc:0.729141
# [9935]	validation-auc:0.686489	train-auc:0.729141
# [9936]	validation-auc:0.686486	train-auc:0.729143
# [9937]	validation-auc:0.686482	train-auc:0.729147
# [9938]	validation-auc:0.686482	train-auc:0.729147
# [9939]	validation-auc:0.686482	train-auc:0.729147
# [9940]	validation-auc:0.686482	train-auc:0.729147
# [9941]	validation-auc:0.686482	train-auc:0.729147
# [9942]	validation-auc:0.686482	train-auc:0.729147
# [9943]	validation-auc:0.686483	train-auc:0.729147
# [9944]	validation-auc:0.686483	train-auc:0.729147
# [9945]	validation-auc:0.686483	train-auc:0.729147
# [9946]	validation-auc:0.686483	train-auc:0.729147
# [9947]	validation-auc:0.686483	train-auc:0.729147
# [9948]	validation-auc:0.686487	train-auc:0.72915
# [9949]	validation-auc:0.686487	train-auc:0.72915
# [9950]	validation-auc:0.686487	train-auc:0.72915
# [9951]	validation-auc:0.686486	train-auc:0.729155
# [9952]	validation-auc:0.68649	train-auc:0.729157
# [9953]	validation-auc:0.686487	train-auc:0.72916
# [9954]	validation-auc:0.686487	train-auc:0.72916
# [9955]	validation-auc:0.686494	train-auc:0.729164
# [9956]	validation-auc:0.686493	train-auc:0.72917
# [9957]	validation-auc:0.686498	train-auc:0.729171
# [9958]	validation-auc:0.686495	train-auc:0.729171
# [9959]	validation-auc:0.686499	train-auc:0.729175
# [9960]	validation-auc:0.686501	train-auc:0.729174
# [9961]	validation-auc:0.686507	train-auc:0.729177
# [9962]	validation-auc:0.686503	train-auc:0.729179
# [9963]	validation-auc:0.686503	train-auc:0.72918
# [9964]	validation-auc:0.686502	train-auc:0.729181
# [9965]	validation-auc:0.686502	train-auc:0.729181
# [9966]	validation-auc:0.686501	train-auc:0.729183
# [9967]	validation-auc:0.686508	train-auc:0.729186
# [9968]	validation-auc:0.686508	train-auc:0.729186
# [9969]	validation-auc:0.686508	train-auc:0.729186
# [9970]	validation-auc:0.686507	train-auc:0.729189
# [9971]	validation-auc:0.686506	train-auc:0.72919
# [9972]	validation-auc:0.686506	train-auc:0.72919
# [9973]	validation-auc:0.686506	train-auc:0.72919
# [9974]	validation-auc:0.686506	train-auc:0.72919
# [9975]	validation-auc:0.686506	train-auc:0.72919
# [9976]	validation-auc:0.686509	train-auc:0.729193
# [9977]	validation-auc:0.686509	train-auc:0.729193
# [9978]	validation-auc:0.686509	train-auc:0.729193
# [9979]	validation-auc:0.68651	train-auc:0.729193
# [9980]	validation-auc:0.686507	train-auc:0.729197
# [9981]	validation-auc:0.686507	train-auc:0.729197
# [9982]	validation-auc:0.686498	train-auc:0.7292
# [9983]	validation-auc:0.686498	train-auc:0.7292
# [9984]	validation-auc:0.686498	train-auc:0.7292
# [9985]	validation-auc:0.686498	train-auc:0.7292
# [9986]	validation-auc:0.686498	train-auc:0.7292
# [9987]	validation-auc:0.686505	train-auc:0.729203
# [9988]	validation-auc:0.6865	train-auc:0.729202
# [9989]	validation-auc:0.686489	train-auc:0.729203
# [9990]	validation-auc:0.68649	train-auc:0.729207
# [9991]	validation-auc:0.686485	train-auc:0.729211
# [9992]	validation-auc:0.686485	train-auc:0.729211
# [9993]	validation-auc:0.686485	train-auc:0.729211
# [9994]	validation-auc:0.686485	train-auc:0.729211
# [9995]	validation-auc:0.686484	train-auc:0.72922
# [9996]	validation-auc:0.686482	train-auc:0.72922
# [9997]	validation-auc:0.686484	train-auc:0.729221
# [9998]	validation-auc:0.686481	train-auc:0.72922
# [9999]	validation-auc:0.686478	train-auc:0.729222
# CPU times: user 5h 7min 35s, sys: 23.6 s, total: 5h 7min 58s
# Wall time: 9min 49s

# %%
bst
